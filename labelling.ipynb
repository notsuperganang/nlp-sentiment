# %% [markdown]
# # 💡 **AI Labeling yang Super Canggih!** 🚀
#
# Notebook ini dirancang untuk **melabeli data secara otomatis menggunakan Large Language Model (LLM)**. 🔥💡 Setelah melalui tahap **scraping dan preprocessing**, kini saatnya **mengoptimalkan data dengan AI** agar siap digunakan dalam analisis lebih lanjut!
#
# 🎯 **Apa yang akan kita lakukan?**
# ✅ Menggunakan **LLM untuk memberikan label otomatis** pada dataset
# ✅ Meningkatkan efisiensi dengan **otomatisasi labeling berbasis AI** 🤖
# ✅ Menyiapkan data agar **siap pakai** untuk model Machine Learning atau analisis lanjutan
#
# Mari kita mulai perjalanan eksplorasi data ini! 📊✨

# %% [markdown]
# ## 📥 **Import Library Penting**
# Agar semua berjalan dengan mulus, kita perlu mempersiapkan senjata utama: pustaka Python yang akan membantu analisis kita! 🛠️🐍
#
# 📝 **Catatan:** Pastikan pustaka ini sudah terinstal di environment-mu!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import math
import csv
import random
import time
import pandas as pd
from tqdm import tqdm
from g4f.client import Client

# %% [markdown]
# ## 💾 **Memuat Data yang Telah Dibersihkan!** 🏗️📊
#
# Pada tahap ini, kita akan **membaca dataset hasil preprocessing** menggunakan `pandas`. Dataset ini berada dalam file CSV bernama **`clean_data.csv`**, yang berisi berbagai tahap pembersihan teks dari hasil scraping.
#
# 📌 **Kolom Penting dalam Dataset:**
# 🔹 `text` → Teks asli sebelum preprocessing ✍️
# 🔹 `extracted_text` → Teks yang sudah diekstrak dari komentar 💬
# 🔹 `cleaned_text` → Hasil pembersihan dari karakter tidak perlu 🚮
# 🔹 `normalized_text` → Teks yang sudah dinormalisasi dengan ejaan yang lebih rapi ✨
#
# 📊 **Jumlah Data**: Dataset ini memiliki **16.555 baris** dan **14 kolom**!
# 📌 Dengan dataset yang telah **dibersihkan & dinormalisasi**, kita siap untuk masuk ke tahap **labelling otomatis menggunakan LLM**! 🚀🔥

# %%
df = pd.read_csv('full-data/result/clean_data.csv')

df
# Out:
#                                                     text  \
# 0      R a d i t’s comment: pasti pada muak bngt ting...
# 1      zulfa suci lestari’s comment: syarat di indo :...
# 2      matayu’s comment: bukan ga nasionalis tapi rea...
# 3      TongTong SONG’s comment: di jepang mudah cari ...
# 4      shella.’s comment: ingat GUYS. belum terlambat...
# ...                                                  ...
# 16550                             18Maret🥳’s comment: ok
# 16551         yanfar2411’s comment: Assalamu'alaikum kak
# 16552                   Rudi Saputra’s comment: ikutt🔥🔥🔥
# 16553                             26158’s comment: gasss
# 16554                                  .’s comment: ikut
#
#                                           extracted_text  \
# 0          pasti pada muak bngt tinggal di Indonesian 😭😭
# 1      syarat di indo : harus berpenampilan menarik.\...
# 2                     bukan ga nasionalis tapi realistis
# 3      di jepang mudah cari kerja di indonesia harus ...
# 4      ingat GUYS. belum terlambat kalo mau mulai dar...
# ...                                                  ...
# 16550                                                 ok
# 16551                               Assalamu'alaikum kak
# 16552                                           ikutt🔥🔥🔥
# 16553                                              gasss
# 16554                                               ikut
#
#                                             cleaned_text  \
# 0             pasti pada muak bngt tinggal di indonesian
# 1      syarat di indo harus berpenampilan menarik dar...
# 2                     bukan ga nasionalis tapi realistis
# 3      di jepang mudah cari kerja di indonesia harus ...
# 4      ingat guys belum terlambat kalo mau mulai dari...
# ...                                                  ...
# 16550                                                 ok
# 16551                                assalamualaikum kak
# 16552                                              ikutt
# 16553                                              gasss
# 16554                                               ikut
#
#                                          normalized_text  \
# 0            pasti pada muak banget tinggal di indonesia
# 1      syarat di indonesia harus berpenampilan menari...
# 2                  bukan tidak nasionalis tapi realistis
# 3      di jepang mudah cari kerja di indonesia harus ...
# 4      ingat guys belum terlambat kalau mau mulai dar...
# ...                                                  ...
# 16550                                                 ok
# 16551                                assalamualaikum kak
# 16552                                              ikutt
# 16553                                                gas
# 16554                                               ikut
#
#                          tokens_no_stopwords_and_stemmed  \
# 0             ['muak', 'banget', 'tinggal', 'indonesia']
# 1      ['syarat', 'indonesia', 'tampil', 'tarik', 'si...
# 2                            ['nasionalis', 'realistis']
# 3      ['jepang', 'mudah', 'cari', 'kerja', 'indonesi...
# 4                                             ['lambat']
# ...                                                  ...
# 16550                                             ['ok']
# 16551                         ['assalamualaikum', 'kak']
# 16552                                          ['ikutt']
# 16553                                            ['gas']
# 16554                                                 []
#
#                tokens_no_stopwords_and_stemmed_formatted  \
# 0                     [muak, banget, tinggal, indonesia]
# 1      [syarat, indonesia, tampil, tarik, situ, aja, ...
# 2                                [nasionalis, realistis]
# 3      [jepang, mudah, cari, kerja, indonesia, avatar...
# 4                                               [lambat]
# ...                                                  ...
# 16550                                               [ok]
# 16551                             [assalamualaikum, kak]
# 16552                                            [ikutt]
# 16553                                              [gas]
# 16554                                                 []
#
#                                             processed  likes  reply_count  \
# 0                       muak banget tinggal indonesia   5290           50
# 1        syarat indonesia tampil tarik situ aja kalah   1711           14
# 2                                nasionalis realistis   1698            3
# 3      jepang mudah cari kerja indonesia avatar kerja   1256           13
# 4                                              lambat    613            2
# ...                                               ...    ...          ...
# 16550                                              ok      0            0
# 16551                             assalamualaikum kak      0            0
# 16552                                           ikutt      0            0
# 16553                                             gas      0            0
# 16554                                             NaN      0            0
#
#       created_time_formatted  is_pinned  is_reply  user_verified  \
# 0        2025-02-17 05:41:38      False      True          False
# 1        2025-02-17 05:26:15      False      True          False
# 2        2025-02-17 05:54:08      False      True          False
# 3        2025-02-17 05:16:01      False      True          False
# 4        2025-02-17 05:11:20      False      True          False
# ...                      ...        ...       ...            ...
# 16550    2025-02-14 11:04:16      False      True          False
# 16551    2025-02-14 11:04:15      False      True          False
# 16552    2025-02-14 11:01:28      False      True          False
# 16553    2025-02-14 11:01:27      False      True          False
# 16554    2025-02-14 11:01:00      False      True          False
#
#       comment_language
# 0                   id
# 1                   id
# 2                   id
# 3                   id
# 4                   id
# ...                ...
# 16550               en
# 16551               ms
# 16552               id
# 16553               id
# 16554               id
#
# [16555 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# text                                            0
# extracted_text                                  0
# cleaned_text                                 2384
# normalized_text                              2384
# tokens_no_stopwords_and_stemmed                 0
# tokens_no_stopwords_and_stemmed_formatted       0
# processed                                    2599
# likes                                           0
# reply_count                                     0
# created_time_formatted                          0
# is_pinned                                       0
# is_reply                                        0
# user_verified                                   0
# comment_language                                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# text                                         0
# extracted_text                               0
# cleaned_text                                 0
# normalized_text                              0
# tokens_no_stopwords_and_stemmed              0
# tokens_no_stopwords_and_stemmed_formatted    0
# processed                                    0
# likes                                        0
# reply_count                                  0
# created_time_formatted                       0
# is_pinned                                    0
# is_reply                                     0
# user_verified                                0
# comment_language                             0
# dtype: int64

# %%
df.to_csv('full-data/result/clean_data2.csv', index=False)

# %% [markdown]
# ## 🧹 **Deduplication: Membersihkan Data dari Duplikasi!** 🔄📊
#
# Pada tahap ini, kita akan **menghapus duplikasi dalam dataset** menggunakan `pandas`. Dataset **`clean_data.csv`** mengandung teks yang mungkin memiliki **duplikasi**, sehingga kita perlu menyaring hanya **teks unik** untuk menjaga kualitas data.
#
# ### 📌 **Mengapa Deduplication Itu Penting?**
# ✅ **Mengurangi redundansi** dalam data
# ✅ **Meningkatkan efisiensi** pemrosesan
# ✅ **Meningkatkan akurasi model** dengan data yang lebih bersih
#
# ### 🔍 **Bagaimana Cara Kerjanya?**
# 1️⃣ **Memuat dataset** dengan `pandas`
# 2️⃣ **Mengidentifikasi duplikasi** berdasarkan kolom `extracted_text`
# 3️⃣ **Menghitung jumlah duplikasi** untuk memahami skala masalah
# 4️⃣ **Menghapus duplikasi** dengan memilih teks yang memiliki **engagement (likes + reply_count) tertinggi**
# 5️⃣ **Menyimpan dataset yang telah dibersihkan** ke **`clean_data_deduplicated.csv`**
#
# ### 📊 **Ringkasan Proses Deduplication**
# 📂 **Dataset awal:** 16.555 baris
# 🔄 **Duplikasi ditemukan:** 2770 baris
# ✅ **Dataset akhir setelah deduplication:** 13785 baris

# %%
# Input and output file paths
INPUT_CSV = 'full-data/result/clean_data2.csv'
OUTPUT_CSV = 'full-data/result/clean_data_deduplicated.csv'

def deduplicate_dataset():
    print("📊 Loading dataset...")
    # Read the original dataset
    df = pd.read_csv(INPUT_CSV)
    total_records = len(df)
    print(f"✅ Dataset loaded. Total records: {total_records}")
    
    # Count unique texts
    unique_texts_count = df['extracted_text'].nunique()
    print(f"📝 Unique texts in dataset: {unique_texts_count}")
    print(f"🔄 Duplicates: {total_records - unique_texts_count} records")
    
    # Identify duplicates
    duplicate_mask = df.duplicated(subset=['extracted_text'], keep=False)
    duplicates_df = df[duplicate_mask]
    print(f"🔍 Found {len(duplicates_df)} records with duplicate text")
    
    # Sample of duplicates (optional, for inspection)
    if len(duplicates_df) > 0:
        print("\n📋 Sample of duplicate texts:")
        # Group by text to show examples of duplicates
        for i, (text, group) in enumerate(duplicates_df.groupby('extracted_text')):
            if i >= 3:  # Show just 3 examples
                break
            print(f"  Text #{i+1}: '{text[:50]}{'...' if len(text) > 50 else ''}'")
            print(f"  Appears {len(group)} times")
            print(f"  Sample record: {group.iloc[0][['likes', 'reply_count']].to_dict()}")
            print()
    
    # Perform deduplication
    print("\n🧹 Removing duplicates...")
    
    # Create a temporary metric for engagement
    df['engagement'] = df['likes'].fillna(0) + df['reply_count'].fillna(0)
    
    # Sort by engagement in descending order, then deduplicate
    df = df.sort_values('engagement', ascending=False)
    deduplicated_df = df.drop_duplicates(subset=['extracted_text'], keep='first')
    
    # Remove the temporary engagement column
    deduplicated_df = deduplicated_df.drop('engagement', axis=1)
    
    print(f"✅ Deduplication complete. Records remaining: {len(deduplicated_df)}")
    print(f"🗑️ Removed {total_records - len(deduplicated_df)} duplicate records")
    
    # Save deduplicated dataset
    print(f"💾 Saving deduplicated dataset to {OUTPUT_CSV}...")
    deduplicated_df.to_csv(OUTPUT_CSV, index=False)
    print("✅ Deduplicated dataset saved successfully!")

if __name__ == "__main__":
    # Make sure output directory exists
    os.makedirs(os.path.dirname(OUTPUT_CSV), exist_ok=True)
    deduplicate_dataset()
    print("✨ Process completed!")
# Out:
# 📊 Loading dataset...
# ✅ Dataset loaded. Total records: 13956
# 📝 Unique texts in dataset: 13352
# 🔄 Duplicates: 604 records
# 🔍 Found 885 records with duplicate text
#
# 📋 Sample of duplicate texts:
#   Text #1: '"Terlahir disini tanpa diminta,menjalaninya hampir...'
#   Appears 13 times
#   Sample record: {'likes': 613, 'reply_count': 8}
#
#   Text #2: '#kabur aja dulu'
#   Appears 2 times
#   Sample record: {'likes': 0, 'reply_count': 0}
#
#   Text #3: '#kaburajadulu ang ang ang ang 🤣'
#   Appears 2 times
#   Sample record: {'likes': 0, 'reply_count': 0}
#
#
# 🧹 Removing duplicates...
# ✅ Deduplication complete. Records remaining: 13352
# 🗑️ Removed 604 duplicate records
# 💾 Saving deduplicated dataset to full-data/result/clean_data_deduplicated.csv...
# ✅ Deduplicated dataset saved successfully!
# ✨ Process completed!

# %% [markdown]
# ## ✂️ **Membagi Dataset Menjadi 6 Bagian** 🏗️📊
#
# Dalam tahap ini, kita akan **membagi dataset yang telah dide-duplikasi** menjadi **6 bagian** menggunakan `pandas`. Tujuan utama dari proses ini adalah **mengurangi risiko crash** saat melakukan **labelling otomatis menggunakan API LLM**.
#
# ### 🔍 **Mengapa Perlu Dibagi Menjadi 6 Bagian?**
# ✅ **Mencegah crash** akibat pemrosesan data yang terlalu besar dalam satu waktu
# ✅ **Mempercepat eksekusi** dengan membagi beban kerja menjadi batch yang lebih kecil
# ✅ **Memudahkan troubleshooting** jika terjadi error saat labelling
# ✅ **Memastikan distribusi data yang merata** agar proses labelling lebih optimal
#
# ### 📌 **Bagaimana Cara Kerjanya?**
# 1️⃣ **Memuat dataset deduplikasi** dari `clean_data_deduplicated.csv`
# 2️⃣ **Menghitung ukuran setiap bagian**, dengan menyesuaikan sisa data agar tidak ada kehilangan baris
# 3️⃣ **Mengacak urutan data** untuk memastikan distribusi yang merata
# 4️⃣ **Membagi dataset menjadi 6 bagian** dengan jumlah baris yang seimbang
# 5️⃣ **Menyimpan setiap bagian ke file CSV terpisah** di dalam folder `chunks/`
#
# ### 📊 **Ringkasan Proses Pembagian Dataset**
# 📂 **Dataset awal:** 13785 baris
# 📦 **Jumlah chunk:** 6
# 🔄 **Ukuran tiap chunk:** Sebagian besar memiliki `13785/6` baris, dengan sedikit penyesuaian agar merata
# 📁 **Lokasi hasil:** `full-data/result/chunks/`
#
# Dengan dataset yang telah dibagi menjadi **6 bagian**, kita siap melanjutkan ke tahap **labelling otomatis menggunakan LLM** dengan risiko crash yang lebih rendah! 🚀🔥

# %%
# Configuration
INPUT_CSV = 'full-data/result/clean_data_deduplicated.csv'
OUTPUT_DIR = 'full-data/result/chunks/'
NUM_CHUNKS = 6
RANDOM_SEED = 42  # For reproducibility if you want to shuffle the data

def split_dataset():
    # Create output directory if it doesn't exist
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    print("📊 Loading deduplicated dataset...")
    df = pd.read_csv(INPUT_CSV)
    total_records = len(df)
    print(f"✅ Dataset loaded successfully. Total unique records: {total_records}")
    
    # Calculate chunk size and distribution
    base_chunk_size = math.floor(total_records / NUM_CHUNKS)
    remainder = total_records % NUM_CHUNKS
    
    print(f"\n📦 Splitting dataset into {NUM_CHUNKS} chunks:")
    print(f"  - Base chunk size: {base_chunk_size} records per chunk")
    if remainder > 0:
        print(f"  - First {remainder} chunks will have {base_chunk_size + 1} records")
    
    # Optional: shuffle dataset to ensure random distribution
    # Comment this out if you want to maintain original order
    df = df.sample(frac=1, random_state=RANDOM_SEED).reset_index(drop=True)
    print("🔀 Shuffled dataset to ensure random distribution of records")
    
    # Split and save chunks
    start_idx = 0
    for i in range(NUM_CHUNKS):
        # Calculate size of current chunk (add 1 to first 'remainder' chunks)
        current_chunk_size = base_chunk_size + (1 if i < remainder else 0)
        end_idx = start_idx + current_chunk_size
        
        # Extract chunk
        chunk_df = df.iloc[start_idx:end_idx].copy()
        
        # Generate output filename
        output_file = os.path.join(OUTPUT_DIR, f"chunk_{i+1}_of_{NUM_CHUNKS}.csv")
        
        # Save chunk
        chunk_df.to_csv(output_file, index=False)
        
        # Print statistics for this chunk
        print(f"\n✅ Chunk {i+1}/{NUM_CHUNKS} created:")
        print(f"  - Records: {len(chunk_df)}")
        print(f"  - Range: rows {start_idx+1} to {end_idx}")
        print(f"  - Saved to: {output_file}")
        
        # Update start index for next chunk
        start_idx = end_idx
    
    print("\n🎉 Dataset splitting completed successfully!")
    print(f"📁 All chunks saved to: {OUTPUT_DIR}")
    print("\nTo process these chunks, update your sentiment labeling script with:")
    print("INPUT_CSV = '[path to chunk file]'")

if __name__ == "__main__":
    split_dataset()
# Out:
# 📊 Loading deduplicated dataset...
# ✅ Dataset loaded successfully. Total unique records: 13352
#
# 📦 Splitting dataset into 6 chunks:
#   - Base chunk size: 2225 records per chunk
#   - First 2 chunks will have 2226 records
# 🔀 Shuffled dataset to ensure random distribution of records
#
# ✅ Chunk 1/6 created:
#   - Records: 2226
#   - Range: rows 1 to 2226
#   - Saved to: full-data/result/chunks/chunk_1_of_6.csv
#
# ✅ Chunk 2/6 created:
#   - Records: 2226
#   - Range: rows 2227 to 4452
#   - Saved to: full-data/result/chunks/chunk_2_of_6.csv
#
# ✅ Chunk 3/6 created:
#   - Records: 2225
#   - Range: rows 4453 to 6677
#   - Saved to: full-data/result/chunks/chunk_3_of_6.csv
#
# ✅ Chunk 4/6 created:
#   - Records: 2225
#   - Range: rows 6678 to 8902
#   - Saved to: full-data/result/chunks/chunk_4_of_6.csv
#
# ✅ Chunk 5/6 created:
#   - Records: 2225
#   - Range: rows 8903 to 11127
#   - Saved to: full-data/result/chunks/chunk_5_of_6.csv
#
# ✅ Chunk 6/6 created:
#   - Records: 2225
#   - Range: rows 11128 to 13352
#   - Saved to: full-data/result/chunks/chunk_6_of_6.csv
#
# 🎉 Dataset splitting completed successfully!
# 📁 All chunks saved to: full-data/result/chunks/
#
# To process these chunks, update your sentiment labeling script with:
# INPUT_CSV = '[path to chunk file]'

# %% [markdown]
# ## 🚀 **Labeling Sentimen Otomatis**
#
# ### 📝 **Overview Proses Labeling**
#
# Kode yang disediakan merupakan sistem yang dirancang untuk melakukan labeling sentimen secara otomatis terhadap komentar TikTok dengan topik "#KaburAjaDulu". Berikut adalah penjelasan rinci tentang cara kerjanya:
#
# ### ⚙️ **Konfigurasi Kode**
#
# ```python
# # Konfigurasi
# INPUT_CSV = 'full-data/result/chunks/chunk_1_of_6.csv'  # Data yang telah dipreprocessing
# PROGRESS_CSV = 'label-data/progress_sentiment_1_to_6.csv'  # File untuk menyimpan progres
# OUTPUT_CSV = 'label-data/labeled_sentiment_1_to_6.csv'  # File output hasil labeling
# BATCH_SIZE = 20  # Jumlah teks yang dilabel per batch
# MAX_RETRIES = 5  # Batas percobaan ulang jika terjadi error
# DELAY_BETWEEN_RETRIES = 10  # Waktu jeda antara percobaan dalam detik
# MAX_PROCESSING_TIME = 7200  # Batas waktu proses (dalam detik, default 2 jam)
# ```
#
# Konfigurasi di atas menunjukkan bahwa:
#
# 1. **Pendekatan Chunking**: Data diproses dalam bentuk potongan (chunks) untuk mengelola dataset besar.
# 2. **File Tracking**: Sistem menyimpan progress labeling dalam file terpisah, memungkinkan pelacakan dan melanjutkan proses jika terhenti.
# 3. **Batch Processing**: Teks diproses dalam batch berukuran 20 untuk meningkatkan efisiensi.
# 4. **Mekanisme Retry**: Sistem akan mencoba ulang hingga 5 kali jika terjadi kesalahan.
#
# ## 🧠 **Model yang Digunakan**
#
# Proses labeling menggunakan model GPT-4o-mini melalui library g4f:
#
# ```python
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[{"role": "user", "content": prompt}],
#     temperature=temperature
# )
# ```
#
# Temperatur disesuaikan selama percobaan ulang (makin kecil untuk respons yang lebih deterministik):
# ```python
# temperature = max(0.1, 0.2 - attempt * 0.05)
# ```
#
# ## 📋 **Template Prompt**
#
# Sistem menggunakan dua jenis prompt:
#
# 1. **Prompt Standar** - Digunakan untuk percobaan pertama:
# ```
# Klasifikasikan {batch_size} komentar TikTok berikut mengenai topik "#kaburajadulu" berdasarkan sentimen:
#
# - POSITIF: Mendukung, menyetujui, atau berempati dengan konsep #KaburAjaDulu...
# - NEGATIF: Menolak atau tidak setuju dengan konsep #KaburAjaDulu...
# - NETRAL: Tidak jelas menunjukkan dukungan atau penolakan...
# ```
#
# 2. **Prompt Retry** - Lebih tegas untuk percobaan ulang ketika prompt standar gagal:
# ```
# SANGAT PENTING! Klasifikasikan TEPAT {batch_size} komentar TikTok berikut terkait #KaburAjaDulu:
#
# INSTRUKSI YANG WAJIB DIIKUTI:
# - Berikan TEPAT {batch_size} label...
# ```
#
# ## 🔄 **Alur Proses Utama**
#
# Alur kerja sistem dapat dirangkum dalam beberapa tahap utama:
#
# ### 1️⃣ **Memuat dan Menyiapkan Data**
# ```python
# def load_data():
#     # Memuat dataset utama terlebih dahulu
#     main_df = pd.read_csv(INPUT_CSV)
#
#     # Cek duplikat dan file progress
#     has_duplicates = check_for_duplicates(main_df)
#
#     # Mengelola file progress jika ada
#     if os.path.exists(PROGRESS_CSV):
#         # Proses sinkronisasi dan validasi...
# ```
#
# Fungsi ini bertanggung jawab untuk:
# - Memuat dataset asli
# - Mendeteksi duplikat dalam data
# - Memuat file progress jika ada
# - Memastikan konsistensi label antara file progress dan dataset asli
#
# ### 2️⃣ **Membuat Batch dari Teks Unik**
# ```python
# def create_batches(data):
#     # Identifikasi teks unik yang belum dilabel
#     unlabeled_texts = set()
#     text_to_records = {}
#
#     # Pembagian ke dalam batch
#     batches = []
#     for i in range(0, total_unique, BATCH_SIZE):
#         batch_texts = unique_unlabeled[i:i+BATCH_SIZE]
#         current_batch = [text_to_records[text][0] for text in batch_texts]
#         batches.append(current_batch)
# ```
#
# Fungsi ini:
# - Mengidentifikasi teks unik yang belum dilabel
# - Mengelompokkan data berdasarkan teks untuk menghindari duplikasi
# - Membagi data menjadi batch-batch berukuran tetap
# - Memberikan statistik tentang jumlah teks yang akan diproses
#
# ### 3️⃣ **Proses Labeling dengan Robust Error Handling**
# ```python
# def label_batch(batch):
#     # Mencoba dengan tingkat ketegasan meningkat
#     for attempt in range(MAX_RETRIES):
#         try:
#             # Memilih prompt berdasarkan percobaan
#             if attempt == 0:
#                 prompt = generate_prompt(batch)
#             else:
#                 prompt = RETRY_PROMPT_TEMPLATE.format(...)
#
#             # Memanggil API dengan suhu yang disesuaikan
#             response = client.chat.completions.create(...)
#
#             # Parsing respons
#             result = parse_response(content, batch)
# ```
#
# Fungsi ini menangani:
# - Multiple retry dengan prompt yang berbeda
# - Penyesuaian temperatur model untuk hasil yang lebih konsisten
# - Pengelolaan error dan waktu tunggu antar percobaan
# - Visualisasi distribusi label hasil dari model
#
# ### 4️⃣ **Parsing dan Validasi Respons Model**
# ```python
# def parse_response(response, batch):
#     valid_labels = ['positif', 'negatif', 'netral']
#
#     # Membersihkan respons
#     cleaned_response = response.strip()
#
#     # Menangani berbagai format respons
#     if ',' in cleaned_response:
#         # Format comma-separated
#         raw_labels = []
#         for label in cleaned_response.split(','):
#             # Proses label
#     else:
#         # Format alternatif
#         # ...
#
#     # Verifikasi jumlah label
#     if len(raw_labels) != len(batch):
#         # Handling ketidaksesuaian jumlah...
# ```
#
# Fungsi ini:
# - Mengenali berbagai format respons yang mungkin dari model
# - Memvalidasi bahwa jumlah label sesuai dengan jumlah teks
# - Menerapkan strategi perbaikan jika jumlah label tidak sesuai
# - Mengaplikasikan label ke batch data
#
# ### 5️⃣ **Memastikan Konsistensi Label untuk Teks yang Sama**
# ```python
# def update_original_data(data, labeled_batch):
#     text_to_label = {}
#
#     # Kumpulkan semua teks yang dilabel beserta labelnya
#     for item in labeled_batch:
#         text = item['extracted_text']
#         label = item['sentiment_label']
#         text_to_label[text] = label
#
#     # Update SEMUA record dengan teks yang sama
#     for original in data:
#         text = original['extracted_text']
#         if text in text_to_label:
#             original['sentiment_label'] = text_to_label[text]
# ```
#
# Fungsi ini memastikan:
# - Teks yang identik selalu mendapatkan label yang sama
# - Semua instance dari teks yang sama diupdate bersamaan
# - Menghitung dan melaporkan berapa banyak record yang terpengaruh
#
# ### 6️⃣ **Penyimpanan Progress yang Aman**
# ```python
# def save_progress(data):
#     # Verifikasi sebelum menyimpan
#     total_records = len(df)
#     labeled_count = df['sentiment_label'].notna().sum()
#
#     # Cek inkonsistensi label
#     text_to_labels = {}
#     inconsistent_texts = []
#
#     # Deteksi dan perbaiki inkonsistensi
#     if inconsistent_texts:
#         # Penyeragaman label...
#
#     # Simpan dengan backup
#     backup_file = f"{PROGRESS_CSV}.bak"
#     if os.path.exists(PROGRESS_CSV):
#         os.replace(PROGRESS_CSV, backup_file)
# ```
#
# Fitur-fitur keamanan data meliputi:
# - Verifikasi data sebelum penyimpanan
# - Deteksi dan perbaikan inkonsistensi label
# - Pembuatan file backup sebelum penyimpanan
# - Mekanisme pemulihan jika penyimpanan gagal
#
# ### 📊 **Pengelolaan Teks Duplikat**
#
# Kode ini memberikan perhatian khusus pada penanganan teks duplikat:
#
# 1. **Deteksi Duplikat**:
# ```python
# def check_for_duplicates(df):
#     # Hitung kemunculan setiap teks
#     text_counts = df['extracted_text'].value_counts()
#
#     # Temukan nilai yang muncul lebih dari sekali
#     duplicates = text_counts[text_counts > 1]
# ```
#
# 2. **Penyeragaman Label**:
# ```python
# def deduplicate_progress_file():
#     # Dapatkan semua teks berlabel dan labelnya
#     labeled_df = df[df['sentiment_label'].notna()].copy()
#     labeled_texts = {}
#
#     # Untuk setiap teks berlabel, simpan label yang paling umum
#     for text, group in labeled_df.groupby('extracted_text'):
#         label_counts = group['sentiment_label'].value_counts()
#         most_common_label = label_counts.index[0]
#         labeled_texts[text] = most_common_label
# ```
#
# 3. **Konsistensi Update**:
# ```python
# # Dalam fungsi update_original_data dan save_progress,
# # sistem memastikan bahwa semua instance dari teks yang sama
# # mendapatkan label yang identik
# ```
#
# ### ⏱️ **Fitur Time Management**
#
# Kode dilengkapi dengan fitur manajemen waktu untuk mengontrol durasi eksekusi:
#
# ```python
# # Dalam fungsi main():
# start_time = time.time()
#
# # Selama pemrosesan batch:
# elapsed_time = time.time() - start_time
# if elapsed_time > MAX_PROCESSING_TIME:
#     print(f"\n⏱️ Batas waktu pemrosesan ({MAX_PROCESSING_TIME/3600:.1f} jam) tercapai.")
#     break
# ```
#
# Ini memungkinkan:
# - Pembatasan waktu proses keseluruhan (default 2 jam)
# - Pelaporan progress pada titik pemberhentian
# - Penyimpanan semua label yang sudah dikumpulkan sebelum pemberhentian
#
# ### 📈 **Pelaporan dan Visualisasi Progress**
#
# Kode dilengkapi dengan pelaporan komprehensif menggunakan:
#
# 1. **Statistik Awal dan Akhir**:
# ```python
# print(f"\n📊 STATISTIK DATASET:")
# print(f"  - Total record: {total_records}")
# print(f"  - Total teks unik: {unique_texts}")
# # ... dan seterusnya
# ```
#
# 2. **Progress Bar (tqdm)**:
# ```python
# with tqdm(total=unique_unlabeled, desc="🚀 Progress Labeling", unit="teks") as pbar:
#     # Proses batch dan update progress bar
#     pbar.update(len(labeled_batch))
# ```
#
# 3. **Visualisasi Hasil Per Batch**:
# ```python
# labels = [item['sentiment_label'] for item in result]
# label_counts = {label: labels.count(label) for label in set(labels)}
# print("🏷️ Label terdeteksi:")
# for lbl, count in sorted(label_counts.items(), key=lambda x: -x[1]):
#     print(f"  - {lbl}: {count}x ({count/len(labels)*100:.1f}%)")
# ```
#
# ### 🔄 **Penggunaan untuk Multiple Chunks**
#
# Seperti yang disebutkan di catatan akhir:
#
# > "Konfigurasi akan diupdate untuk setiap chunk dan fungsi main di panggil sekali untuk setiap chunk"
#
# Ini berarti sistem dirancang untuk memproses dataset besar dengan cara:
#
# 1. Membagi dataset utama menjadi beberapa chunk (`chunk_1_of_6.csv`, `chunk_2_of_6.csv`, dst.)
# 2. Mengupdate konfigurasi (variabel `INPUT_CSV`, `PROGRESS_CSV`, dan `OUTPUT_CSV`) untuk setiap chunk
# 3. Memanggil fungsi `main()` secara berurutan untuk setiap chunk
# 4. Menggabungkan hasil akhir untuk analisis keseluruhan
#
# Pendekatan ini memungkinkan:
# - Pemrosesan dataset besar tanpa membebani memori
# - Melanjutkan dari titik tertentu jika terjadi kegagalan
# - Pelacakan progress terpisah untuk setiap chunk
# - Paralelisasi potensial jika dijalankan di beberapa instance
#
# ### 🛡️ **Strategi Error Handling**
#
# Kode dilengkapi dengan multiple layer error handling:
#
# 1. **Try/Except pada Level Fungsi**:
# ```python
# try:
#     # Operasi utama
# except Exception as e:
#     print(f"❌ Error saat X: {str(e)}")
#     # Strategi pemulihan
# ```
#
# 2. **Try/Except pada Level Aplikasi**:
# ```python
# if __name__ == "__main__":
#     try:
#         main()
#     except KeyboardInterrupt:
#         # Handling interupsi manual
#     except Exception as e:
#         # Handling fatal error
# ```
#
# 3. **Recovery dari Backup**:
# ```python
# try:
#     if os.path.exists(f"{PROGRESS_CSV}.bak"):
#         os.replace(f"{PROGRESS_CSV}.bak", PROGRESS_CSV)
#         print("✅ Pemulihan dari backup berhasil")
# except:
#     print("❌ Gagal memulihkan dari backup")
# ```
#
# ### 🌟 **Kelebihan Desain Kode**
#
# 1. **Robust terhadap Kegagalan**: Dapat melanjutkan dari titik terakhir jika terjadi interupsi
# 2. **Efisien dengan Data Besar**: Pendekatan chunking dan batch processing
# 3. **Konsistensi Data**: Memastikan teks identik mendapat label yang sama
# 4. **Optimisasi Biaya API**: Hanya memproses teks unik, mengelompokkan teks duplikat
# 5. **Visualisasi Progress**: Memberikan insight selama proses berjalan
# 6. **Adaptif terhadap Respons Model**: Dapat menangani berbagai format output dari model
#
# ### 🔄 **Cara Menjalankan untuk Semua Chunk**
#
# Untuk menjalankan kode ini pada semua 6 chunk, Anda perlu membuat script wrapper yang mengupdate konfigurasi dan memanggil main untuk setiap chunk:
#
# ```python
# # Contoh pseudocode untuk menjalankan semua chunk
# for i in range(1, 7):  # Total 6 chunk
#     # Update konfigurasi untuk chunk ini
#     INPUT_CSV = f'full-data/result/chunks/chunk_{i}_of_6.csv'
#     PROGRESS_CSV = f'label-data/progress_sentiment_{i}_to_6.csv'
#     OUTPUT_CSV = f'label-data/labeled_sentiment_{i}_to_6.csv'
#
#     # Panggil fungsi main
#     print(f"\n\n{'='*60}")
#     print(f"MEMULAI PROSES UNTUK CHUNK {i}/6")
#     print(f"{'='*60}\n")
#
#     # Jalankan proses labeling untuk chunk ini
#     main()
#
#     print(f"\n{'='*60}")
#     print(f"SELESAI MEMPROSES CHUNK {i}/6")
#     print(f"{'='*60}\n\n")
# ```
#
# Dengan pendekatan ini, sistem dapat memproses dataset skala besar secara bertahap dan dengan penggunaan memori yang terkontrol.

# %%
import pandas as pd
import numpy as np
import os
import csv
import random
import time
from tqdm import tqdm
from g4f.client import Client

# Konfigurasi
INPUT_CSV = ''  # Data yang telah dipreprocessing
PROGRESS_CSV = ''  # File untuk menyimpan progres
OUTPUT_CSV = ''  # File output hasil labeling
BATCH_SIZE = 20  # Jumlah teks yang dilabel per batch
MAX_RETRIES = 5  # Batas percobaan ulang jika terjadi error
DELAY_BETWEEN_RETRIES = 10  # Waktu jeda antara percobaan dalam detik
MAX_PROCESSING_TIME = 7200  # Batas waktu proses (dalam detik, default 2 jam)

# Pastikan direktori output ada
os.makedirs('label-data', exist_ok=True)

# Inisialisasi client g4f
client = Client()

# Template Prompt
PROMPT_TEMPLATE = """
Klasifikasikan {batch_size} komentar TikTok berikut mengenai topik "#kaburajadulu" berdasarkan sentimen:

- POSITIF: Mendukung, menyetujui, atau berempati dengan konsep #KaburAjaDulu. Komentar yang mengekspresikan keinginan untuk pindah ke luar negeri.
- NEGATIF: Menolak atau tidak setuju dengan konsep #KaburAjaDulu. Komentar yang mendorong untuk tetap tinggal di Indonesia.
- NETRAL: Tidak jelas menunjukkan dukungan atau penolakan terhadap konsep #KaburAjaDulu. Komentar yang hanya informatif.

INSTRUKSI PENTING:
1. Berikan TEPAT {batch_size} label (tidak boleh kurang atau lebih)
2. Gunakan hanya: positif, negatif, atau netral
3. Format: positif,negatif,netral,... (tanpa spasi setelah koma)

Teks ({batch_size} buah):
{text_list}

Jawaban (harus tepat {batch_size} label):"""

# Template Prompt untuk percobaan ulang (lebih ketat)
RETRY_PROMPT_TEMPLATE = """
SANGAT PENTING! Klasifikasikan TEPAT {batch_size} komentar TikTok berikut terkait #KaburAjaDulu:

INSTRUKSI YANG WAJIB DIIKUTI:
- Berikan TEPAT {batch_size} label (tidak boleh {batch_size_minus} atau {batch_size_plus})
- Format: positif,negatif,netral,... (tanpa spasi setelah koma)
- Hanya gunakan kata-kata berikut: positif, negatif, netral

PEDOMAN SENTIMEN #KABURAJADULU:
- POSITIF = Mendukung keinginan meninggalkan Indonesia, membandingkan kondisi lebih baik di luar negeri
- NEGATIF = Menentang ide pergi dari Indonesia, menyarankan bertahan, kritik terhadap yang ingin pergi
- NETRAL = Tidak jelas mendukung/menolak, hanya menyatakan fakta

Teks ({batch_size} buah):
{text_list}

JAWABAN (HARUS TEPAT {batch_size} LABEL):"""

def check_for_duplicates(df):
    """Check for duplicate extracted_text values and report them"""
    # Count occurrences of each extracted_text value
    text_counts = df['extracted_text'].value_counts()
    
    # Find values that appear more than once
    duplicates = text_counts[text_counts > 1]
    
    if len(duplicates) > 0:
        print(f"⚠️ PERINGATAN: Ditemukan {len(duplicates)} teks unik yang memiliki duplikat")
        print(f"⚠️ Total {duplicates.sum()} record dengan teks duplikat")
        
        # Show some examples of duplicates
        print(f"📝 Contoh teks dengan duplikat:")
        count = 0
        for text, frequency in duplicates.items():
            if count >= 3:  # Show at most 3 examples
                break
            print(f"  {count+1}. '{text[:50]}...' muncul {frequency} kali")
            count += 1
    
    return len(duplicates) > 0

def deduplicate_progress_file():
    """Handles duplication in the progress file to ensure consistent labels"""
    if not os.path.exists(PROGRESS_CSV):
        return False
        
    try:
        # Read progress file
        df = pd.read_csv(PROGRESS_CSV)
        original_count = len(df)
        
        # Check if we have duplicates
        has_dups = check_for_duplicates(df)
        if not has_dups:
            return False
            
        print("🔄 Menyelaraskan label untuk teks yang sama...")
        
        # Get all labeled texts with their labels
        labeled_df = df[df['sentiment_label'].notna()].copy()
        labeled_texts = {}
        
        # For each labeled text, store the most common label
        for text, group in labeled_df.groupby('extracted_text'):
            # Get the most common label for this text
            label_counts = group['sentiment_label'].value_counts()
            most_common_label = label_counts.index[0]
            labeled_texts[text] = most_common_label
            
            # If there are conflicting labels, report it
            if len(label_counts) > 1:
                print(f"⚠️ Teks '{text[:30]}...' memiliki {len(label_counts)} label berbeda. Menggunakan '{most_common_label}'")
        
        # Apply consistent labels to all duplicates
        for idx, row in df.iterrows():
            text = row['extracted_text']
            if text in labeled_texts:
                df.at[idx, 'sentiment_label'] = labeled_texts[text]
        
        # Save the updated progress file
        df.to_csv(PROGRESS_CSV, index=False, quoting=csv.QUOTE_ALL)
        
        # Report how many records were updated
        final_labeled = df['sentiment_label'].notna().sum()
        print(f"✅ Penyelarasan selesai. Total berlabel sekarang: {final_labeled}")
        
        return True
        
    except Exception as e:
        print(f"❌ Error saat menyelaraskan label: {str(e)}")
        return False

def load_data():
    """Load data and handle progress tracking properly"""
    try:
        # Memuat dataset utama terlebih dahulu
        print(f"📊 Memuat dataset dari {INPUT_CSV}...")
        main_df = pd.read_csv(INPUT_CSV)
        total_records = len(main_df)
        print(f"✅ Dataset berhasil dimuat. Total record: {total_records}")
        
        # Check for duplicates in main dataset
        has_duplicates = check_for_duplicates(main_df)
        
        # Cek apakah file progress ada
        if os.path.exists(PROGRESS_CSV):
            print(f"🔍 File progress ditemukan: {PROGRESS_CSV}")
            
            # Fix duplicates in progress file if any
            if has_duplicates:
                deduplicate_progress_file()
                
            try:
                progress_df = pd.read_csv(PROGRESS_CSV)
                progress_count = len(progress_df)
                labeled_count = progress_df['sentiment_label'].notna().sum()
                
                print(f"📈 Status progress: {labeled_count}/{progress_count} record telah dilabel")
                
                # Verifikasi bahwa progress file sesuai dengan dataset utama
                if progress_count != total_records:
                    print(f"⚠️ Jumlah record di file progress ({progress_count}) tidak sama dengan dataset utama ({total_records})")
                    print("🔄 Membuat file progress baru dengan dataset lengkap...")
                    
                    # Membuat progress baru dengan mempertahankan label yang sudah ada
                    main_df['sentiment_label'] = None
                    
                    # Membuat dictionary dari teks ke label dari progress file
                    text_to_label = {}
                    for idx, row in progress_df.iterrows():
                        if pd.notna(row.get('sentiment_label')):
                            text_to_label[row['extracted_text']] = row['sentiment_label']
                    
                    # Salin label yang sudah ada ke dataset utama berdasarkan extracted_text
                    update_count = 0
                    for idx, row in main_df.iterrows():
                        text = row['extracted_text']
                        if text in text_to_label:
                            main_df.at[idx, 'sentiment_label'] = text_to_label[text]
                            update_count += 1
                    
                    # Simpan progress baru
                    main_df.to_csv(PROGRESS_CSV, index=False, quoting=csv.QUOTE_ALL)
                    print(f"✅ File progress baru dibuat dengan {update_count} label yang dipertahankan")
                    return main_df.to_dict('records')
                
                return progress_df.to_dict('records')
            
            except Exception as e:
                print(f"❌ Error membaca file progress: {str(e)}")
                print("🔄 Membuat file progress baru...")
                main_df['sentiment_label'] = None
                main_df.to_csv(PROGRESS_CSV, index=False, quoting=csv.QUOTE_ALL)
                return main_df.to_dict('records')
        
        # Jika tidak ada file progress, buat baru
        print("🆕 Membuat file progress baru...")
        main_df['sentiment_label'] = None
        main_df.to_csv(PROGRESS_CSV, index=False, quoting=csv.QUOTE_ALL)
        return main_df.to_dict('records')
        
    except Exception as e:
        print(f"❌ Error fatal saat memuat data: {str(e)}")
        exit(1)

def create_batches(data):
    """Create batches of unlabeled data with duplicate prevention"""
    # First, identify unique texts that need labeling
    unlabeled_texts = set()
    text_to_records = {}
    
    for record in data:
        text = record.get('extracted_text', '')
        if pd.isna(record.get('sentiment_label')):
            unlabeled_texts.add(text)
            
            # Group records by text to handle duplicates
            if text not in text_to_records:
                text_to_records[text] = []
            text_to_records[text].append(record)
    
    # Create a list of unique unlabeled texts
    unique_unlabeled = list(unlabeled_texts)
    total_unique = len(unique_unlabeled)
    total_records = len(data)
    total_unlabeled_records = len([d for d in data if pd.isna(d.get('sentiment_label'))])
    
    print(f"📋 Statistik data yang belum dilabel:")
    print(f"  - Total record belum berlabel: {total_unlabeled_records}/{total_records}")
    print(f"  - Teks unik belum berlabel: {total_unique}")
    
    if total_unique == 0:
        print("🎉 Semua teks unik telah dilabel! Tidak ada yang perlu diproses.")
        return []
    
    # Shuffle untuk randomisasi
    random.shuffle(unique_unlabeled)
    
    # Buat batch dengan ukuran yang tepat (satu record per teks unik)
    batches = []
    for i in range(0, total_unique, BATCH_SIZE):
        batch_texts = unique_unlabeled[i:i+BATCH_SIZE]
        # Take one record per unique text
        current_batch = [text_to_records[text][0] for text in batch_texts]
        batches.append(current_batch)
    
    print(f"🧮 Membagi {total_unique} teks unik menjadi {len(batches)} batch")
    return batches

def generate_prompt(batch):
    """Generate prompt for the current batch"""
    # Pastikan setiap teks memiliki identifier yang unik (indeks + hash ringkas)
    texts = []
    for idx, item in enumerate(batch):
        text = item['extracted_text']
        if not isinstance(text, str) or text.strip() == '':
            text = "(komentar kosong)"
        texts.append(f"{idx+1}. {text}")
    
    return PROMPT_TEMPLATE.format(
        batch_size=len(batch),
        text_list='\n'.join(texts)
    )

def parse_response(response, batch):
    """Parse model response and handle potential issues"""
    valid_labels = ['positif', 'negatif', 'netral']
    
    try:
        # Clean up the response
        cleaned_response = response.strip()
        
        # Handle multiple potential response formats
        if ',' in cleaned_response:
            # Looks like a comma-separated list
            raw_labels = []
            for label in cleaned_response.split(','):
                label = label.strip().lower()
                if label in valid_labels:
                    raw_labels.append(label)
        else:
            # Try to find a list in the response
            lines = cleaned_response.split('\n')
            for line in lines:
                if all(label in line.lower() for label in valid_labels):
                    # Found a line with all labels
                    raw_labels = []
                    for word in line.lower().split():
                        word = word.strip('.,;:()[]{}"\'-')
                        if word in valid_labels:
                            raw_labels.append(word)
                    if raw_labels:
                        break
            else:
                # No clear list found, try one more method
                raw_labels = []
                for word in cleaned_response.lower().split():
                    word = word.strip('.,;:()[]{}"\'-')
                    if word in valid_labels:
                        raw_labels.append(word)
        
        # Verify we have the right number of labels
        if len(raw_labels) != len(batch):
            print(f"⚠️ Jumlah label ({len(raw_labels)}) tidak sesuai dengan jumlah teks ({len(batch)})")
            
            # Try to fix by extending or truncating
            if len(raw_labels) > len(batch):
                raw_labels = raw_labels[:len(batch)]
                print(f"✂️ Memotong ke {len(batch)} label")
            elif len(raw_labels) < len(batch) and raw_labels:
                # Fill missing labels with the most common label
                most_common = max(set(raw_labels), key=raw_labels.count)
                while len(raw_labels) < len(batch):
                    raw_labels.append(most_common)
                print(f"➕ Menambah hingga {len(batch)} label dengan '{most_common}'")
            else:
                # Can't fix - not enough data
                raise ValueError("Tidak dapat mengekstrak label yang cukup")
        
        # Apply labels to batch
        for i, label in enumerate(raw_labels):
            batch[i]['sentiment_label'] = label
        
        return batch
    
    except Exception as e:
        print(f"❌ Error saat parsing respons: {str(e)}")
        print(f"💬 Respons yang tidak valid: {response}")
        return None

def save_progress(data):
    """Save progress with verification"""
    try:
        df = pd.DataFrame(data)
        
        # Verifikasi sebelum menyimpan
        total_records = len(df)
        labeled_count = df['sentiment_label'].notna().sum()
        
        # Tampilkan informasi verifikasi
        print(f"📊 Verifikasi sebelum menyimpan:")
        print(f"  - Total record: {total_records}")
        print(f"  - Total berlabel: {labeled_count} ({labeled_count/total_records*100:.1f}%)")
        print(f"  - Total belum berlabel: {total_records - labeled_count}")
        
        # Check for any inconsistencies in labeling of duplicate texts
        text_to_labels = {}
        inconsistent_texts = []
        
        for idx, row in df.iterrows():
            text = row['extracted_text']
            label = row.get('sentiment_label')
            
            if pd.notna(label):
                if text not in text_to_labels:
                    text_to_labels[text] = label
                elif text_to_labels[text] != label:
                    inconsistent_texts.append(text)
        
        if inconsistent_texts:
            print(f"⚠️ Ditemukan {len(inconsistent_texts)} teks dengan label tidak konsisten")
            print("🔄 Menyeragamkan label untuk teks yang sama...")
            
            # Fix inconsistencies
            for text in inconsistent_texts:
                # Find all occurrences of this text
                matching_indices = df[df['extracted_text'] == text].index
                # Get all labels for this text
                labels = df.loc[matching_indices, 'sentiment_label'].dropna()
                # Find most common label
                most_common = labels.value_counts().idxmax()
                # Apply consistent label
                df.loc[matching_indices, 'sentiment_label'] = most_common
            
            print(f"✅ Label telah diseragamkan")
            labeled_count = df['sentiment_label'].notna().sum()
            print(f"📊 Setelah penyeragaman: {labeled_count} record berlabel")
        
        # Simpan dengan backup
        backup_file = f"{PROGRESS_CSV}.bak"
        if os.path.exists(PROGRESS_CSV):
            os.replace(PROGRESS_CSV, backup_file)
            print(f"💾 Backup dibuat: {backup_file}")
        
        df.to_csv(PROGRESS_CSV, index=False, quoting=csv.QUOTE_ALL)
        print(f"💾 Progress tersimpan: {labeled_count}/{total_records} ({labeled_count/total_records*100:.1f}%)")
        
        return True
    except Exception as e:
        print(f"❌ Error saat menyimpan progress: {str(e)}")
        print("⚠️ Mencoba memulihkan dari backup...")
        try:
            if os.path.exists(f"{PROGRESS_CSV}.bak"):
                os.replace(f"{PROGRESS_CSV}.bak", PROGRESS_CSV)
                print("✅ Pemulihan dari backup berhasil")
        except:
            print("❌ Gagal memulihkan dari backup")
        return False

def label_batch(batch):
    """Label a batch of texts with robust error handling and retry logic"""
    # Tunjukkan contoh teks yang akan dilabel (hanya beberapa)
    print(f"\n🔍 Contoh teks yang akan dilabel:")
    for i, item in enumerate(batch[:3]):  # Tampilkan maksimal 3
        text = item['extracted_text']
        if not isinstance(text, str):
            text = str(text)
        print(f"  {i+1}. {text[:50]}{'...' if len(text) > 50 else ''}")
    if len(batch) > 3:
        print(f"  ... dan {len(batch) - 3} lainnya")
    
    # Coba dengan tingkat ketegasan yang meningkat
    for attempt in range(MAX_RETRIES):
        try:
            # Gunakan prompt yang lebih tegas untuk percobaan ulang
            if attempt == 0:
                prompt = generate_prompt(batch)
            else:
                prompt = RETRY_PROMPT_TEMPLATE.format(
                    batch_size=len(batch),
                    batch_size_minus=len(batch)-1,
                    batch_size_plus=len(batch)+1,
                    text_list='\n'.join([f"{idx+1}. {item['extracted_text']}" for idx, item in enumerate(batch)])
                )
            
            # Reduce temperature on retries (more deterministic)
            temperature = max(0.1, 0.2 - attempt * 0.05)
            
            print(f"🤖 Memanggil API (percobaan {attempt+1}/{MAX_RETRIES}, temp={temperature:.2f})...")
            
            response = client.chat.completions.create(
                model="gpt-4o-mini",
                messages=[{"role": "user", "content": prompt}],
                temperature=temperature
            )
            
            content = response.choices[0].message.content
            print(f"✅ Respons diterima ({len(content)} karakter)")
            
            # Coba parsing respons
            result = parse_response(content, batch)
            
            if result:
                # Tampilkan distribusi label
                labels = [item['sentiment_label'] for item in result]
                label_counts = {label: labels.count(label) for label in set(labels)}
                print("🏷️ Label terdeteksi:")
                for lbl, count in sorted(label_counts.items(), key=lambda x: -x[1]):
                    print(f"  - {lbl}: {count}x ({count/len(labels)*100:.1f}%)")
                
                return result
            else:
                print(f"⚠️ Gagal mengekstrak label, mencoba lagi...")
            
        except Exception as e:
            print(f"⚠️ Percobaan {attempt+1}/{MAX_RETRIES} gagal: {str(e)}")
        
        # Tunggu sebelum mencoba lagi, dengan waktu yang semakin lama
        retry_delay = DELAY_BETWEEN_RETRIES * (attempt + 1)
        print(f"⏳ Menunggu {retry_delay} detik sebelum mencoba lagi...")
        time.sleep(retry_delay)
    
    print("❌ Semua percobaan gagal untuk batch ini")
    return None

def update_original_data(data, labeled_batch):
    """Update original data with new labels, ensuring ALL matching texts get the same label"""
    text_to_label = {}
    
    # First, collect all the labeled texts and their labels
    for item in labeled_batch:
        text = item['extracted_text']
        label = item['sentiment_label']
        
        if not isinstance(text, str) or not text or pd.isna(label):
            continue
        
        text_to_label[text] = label
    
    # Count how many records will be affected
    affected_count = sum(1 for original in data 
                         if original['extracted_text'] in text_to_label 
                         and pd.isna(original.get('sentiment_label')))
    
    # Now update ALL matching records in the original data
    for original in data:
        text = original['extracted_text']
        if text in text_to_label:
            original['sentiment_label'] = text_to_label[text]
    
    # Report how many texts and total records were updated
    print(f"✅ {len(text_to_label)} teks unik diterapkan ke {affected_count} record yang belum berlabel")
    return affected_count

def main():
    print("\n" + "="*50)
    print("🚀 MEMULAI PROSES LABELING SENTIMENT #KABURAJADULU")
    print("="*50)
    
    # Track processing time
    start_time = time.time()
    processing_count = 0
    
    # Load data
    data = load_data()
    total_records = len(data)
    total_unlabeled = len([d for d in data if pd.isna(d.get('sentiment_label'))])
    
    # Count unique texts
    unique_texts = len(set(d['extracted_text'] for d in data))
    unique_unlabeled = len(set(d['extracted_text'] for d in data if pd.isna(d.get('sentiment_label'))))
    
    print(f"\n📊 STATISTIK DATASET:")
    print(f"  - Total record: {total_records}")
    print(f"  - Total teks unik: {unique_texts}")
    print(f"  - Record berlabel: {total_records - total_unlabeled} ({(total_records - total_unlabeled)/total_records*100:.1f}%)")
    print(f"  - Record belum berlabel: {total_unlabeled} ({total_unlabeled/total_records*100:.1f}%)")
    print(f"  - Teks unik belum berlabel: {unique_unlabeled}")
    
    # Create batches for processing
    batches = create_batches(data)
    
    # Jika semua data sudah berlabel, langsung ke output
    if not batches:
        print("\n✅ Semua data sudah memiliki label. Langsung ke output...")
    else:
        # Process batches with progress tracking
        with tqdm(total=unique_unlabeled, desc="🚀 Progress Labeling", unit="teks") as pbar:
            for batch_idx, batch in enumerate(batches):
                # Check if we've exceeded the time limit
                elapsed_time = time.time() - start_time
                if elapsed_time > MAX_PROCESSING_TIME:
                    print(f"\n⏱️ Batas waktu pemrosesan ({MAX_PROCESSING_TIME/3600:.1f} jam) tercapai.")
                    print(f"📈 Telah memproses {processing_count} dari {unique_unlabeled} teks unik.")
                    break
                
                # Print batch info
                print(f"\n\n{'='*50}")
                print(f"🔖 BATCH {batch_idx+1}/{len(batches)} ({len(batch)} teks unik)")
                print(f"{'='*50}")
                
                # Process the batch
                labeled_batch = label_batch(batch)
                
                if labeled_batch:
                    # Update original data - all copies of each text
                    update_original_data(data, labeled_batch)
                    processing_count += len(labeled_batch)  # Count unique texts, not records
                    
                    # Save progress regularly
                    save_progress(data)
                    
                    # Update progress bar based on unique texts processed
                    pbar.update(len(labeled_batch))
                else:
                    print(f"⚠️ Batch {batch_idx+1} gagal diproses. Melanjutkan ke batch berikutnya...")
    
    # Calculate final statistics
    final_labeled = len([d for d in data if not pd.isna(d.get('sentiment_label'))])
    final_unique_labeled = len(set(d['extracted_text'] for d in data if not pd.isna(d.get('sentiment_label'))))
    
    print(f"\n📊 STATISTIK AKHIR:")
    print(f"  - Total record: {total_records}")
    print(f"  - Total teks unik: {unique_texts}")
    print(f"  - Record berlabel: {final_labeled} ({final_labeled/total_records*100:.1f}%)")
    print(f"  - Record belum berlabel: {total_records - final_labeled} ({(total_records - final_labeled)/total_records*100:.1f}%)")
    print(f"  - Teks unik berlabel: {final_unique_labeled} ({final_unique_labeled/unique_texts*100:.1f}%)")
    
    # Save final output with relevant columns
    print("\n💾 Menyimpan hasil akhir...")
    
    # Define columns to include in output, in case some are missing
    desired_columns = ['text', 'extracted_text', 'cleaned_text', 'normalized_text',
                       'tokens_no_stopwords_and_stemmed', 'processed', 'sentiment_label', 'likes', 'reply_count', 
                       'created_time_formatted', 'comment_languange']
    
    # Get available columns
    available_columns = list(data[0].keys())
    output_columns = [col for col in desired_columns if col in available_columns]
    
    # Create output dataframe
    output_df = pd.DataFrame(data)[output_columns]
    
    # Save output
    output_df.to_csv(OUTPUT_CSV, index=False, quoting=csv.QUOTE_ALL)
    print(f"🎉 PROSES SELESAI! Hasil disimpan di {OUTPUT_CSV}")
    
    # Print execution summary
    elapsed_time = time.time() - start_time
    print(f"\n⏱️ Total waktu eksekusi: {elapsed_time/60:.1f} menit")
    print(f"📊 Record berlabel: {final_labeled}/{total_records} ({final_labeled/total_records*100:.1f}%)")
    print(f"📊 Teks unik berlabel: {final_unique_labeled}/{unique_texts} ({final_unique_labeled/unique_texts*100:.1f}%)")

# %%
for i in range(1, 3):  # proses per 2 chunk
    # Update konfigurasi untuk chunk ini
    INPUT_CSV = f'full-data/result/chunks/chunk_{i}_of_6.csv'
    PROGRESS_CSV = f'label-data/progress_sentiment_{i}_to_6.csv'
    OUTPUT_CSV = f'label-data/labeled_sentiment_{i}_to_6.csv'
    
    # Panggil fungsi main
    print(f"\n\n{'='*60}")
    print(f"MEMULAI PROSES UNTUK CHUNK {i}/6")
    print(f"{'='*60}\n")
    
    # Jalankan proses labeling untuk chunk ini
    main()
    
    print(f"\n{'='*60}")
    print(f"SELESAI MEMPROSES CHUNK {i}/6")
    print(f"{'='*60}\n\n")
# Out:
# ============================================================
# MEMULAI PROSES UNTUK CHUNK 1/6
# ============================================================
#
#
# ==================================================
# 🚀 MEMULAI PROSES LABELING SENTIMENT #KABURAJADULU
# ==================================================
# 📊 Memuat dataset dari full-data/result/chunks/chunk_1_of_6.csv...
# ✅ Dataset berhasil dimuat. Total record: 2226
# 🆕 Membuat file progress baru...
#
# 📊 STATISTIK DATASET:
#   - Total record: 2226
#   - Total teks unik: 2226
#   - Record berlabel: 0 (0.0%)
#   - Record belum berlabel: 2226 (100.0%)
#   - Teks unik belum berlabel: 2226
# 📋 Statistik data yang belum dilabel:
#   - Total record belum berlabel: 2226/2226
#   - Teks unik belum berlabel: 2226
# 🧮 Membagi 2226 teks unik menjadi 112 batch
# 🚀 Progress Labeling:   0%|          | 0/2226 [00:00<?, ?teks/s]
# ==================================================
# 🔖 BATCH 1/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ada yang ngomong. nasionalisme dari hati bukan dar...
#   2. Alhamdulillah.aku klo gak SINGAPORE adik aku gak b...
#   3. jiwa nasionalisme itu menurut saya itu
# ya tetap in...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   1%|          | 20/2226 [00:05<10:06,  3.64teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - positif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 20 (0.9%)
#   - Total belum berlabel: 2206
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 20/2226 (0.9%)
#
#
# ==================================================
# 🔖 BATCH 2/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Saya pro NKRI,Dan jangan tanyakan nasionalisme ana...
#   2. kata-kata nya bahlil seakan nantangin, bukannya ng...
#   3. untung gua udah ikutan udah hampir 4 tahun dan mal...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   2%|▏         | 40/2226 [00:09<08:55,  4.08teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 40 (1.8%)
#   - Total belum berlabel: 2186
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 40/2226 (1.8%)
#
#
# ==================================================
# 🔖 BATCH 3/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. One day
#   2. memangnya para koruptor mereka paling nasionalis ?
#   3. suka ngakak sama orang yang bilang bahwa akan dipe...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   3%|▎         | 60/2226 [00:12<06:43,  5.37teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 60 (2.7%)
#   - Total belum berlabel: 2166
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 60/2226 (2.7%)
#
#
# ==================================================
# 🔖 BATCH 4/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. drpd di sumpah Alquran bikin rakyat susah korupsi ...
#   2. umur 25 serasa umur 70thn.dianggap sepuh🗿 bahkan a...
#   3. bahlil menteri yg kerjaan blunder truss..
# pejabat ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▎         | 80/2226 [00:15<06:12,  5.76teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 80 (3.6%)
#   - Total belum berlabel: 2146
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 80/2226 (3.6%)
#
#
# ==================================================
# 🔖 BATCH 5/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Jangan mau makan gaji umr di masa muda, mimpi mu l...
#   2. tanpa konoha sedari mereka yang bekerja di malaysi...
#   3. mbak jg gak kasih solusi cari cuan jg kan di sosme...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▍         | 100/2226 [00:17<05:13,  6.78teks/s]
# ✅ Respons diterima (161 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 100 (4.5%)
#   - Total belum berlabel: 2126
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 100/2226 (4.5%)
#
#
# ==================================================
# 🔖 BATCH 6/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lah malah nantang, belum tau gen z dia🗿🗿
#   2. yg saya takutkan ketika ditempat lain kitalah yg m...
#   3. Ya .. karena Nasionalisme Pak Bahlil Masya Allah.....
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   5%|▌         | 120/2226 [00:21<06:03,  5.79teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - netral: 6x (30.0%)
#   - negatif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 120 (5.4%)
#   - Total belum berlabel: 2106
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 120/2226 (5.4%)
#
#
# ==================================================
# 🔖 BATCH 7/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Semoga aku bisa tahun ini, lewat jalur langit dlu ...
#   2. Saya nyimak dulu.
#   3. wkwkwk
# klo di umur saya bisa kerja di luar negri
# s...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   6%|▋         | 140/2226 [00:40<14:54,  2.33teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 140 (6.3%)
#   - Total belum berlabel: 2086
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 140/2226 (6.3%)
#
#
# ==================================================
# 🔖 BATCH 8/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yg bikin trust issue ma negara sendiri siapa tak t...
#   2. plis ajak gua pindah keluar negeri 😭
#   3. saya udah di Filipina
# saya tunggu kedatangan nya
# 😊...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   7%|▋         | 160/2226 [00:57<19:03,  1.81teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 160 (7.2%)
#   - Total belum berlabel: 2066
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 160/2226 (7.2%)
#
#
# ==================================================
# 🔖 BATCH 9/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Bismillah otw Kongo.
# #kaburajadulu
#   2. bro bicara nasionalisme. padahal dia penjabat kalo...
#   3. Semoga gua jga gk bercanda🤣
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   8%|▊         | 180/2226 [00:59<13:53,  2.45teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 180 (8.1%)
#   - Total belum berlabel: 2046
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 180/2226 (8.1%)
#
#
# ==================================================
# 🔖 BATCH 10/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. info jalur
#   2. Sudah tidak percaya pa...😉😉
#   3. kerja di luar negri itu bukan berarti gak nasional...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   9%|▉         | 200/2226 [01:01<10:35,  3.19teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 200 (9.0%)
#   - Total belum berlabel: 2026
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 200/2226 (9.0%)
#
#
# ==================================================
# 🔖 BATCH 11/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Oke siap 🫡 otw 😎😎😎
#   2. kabur aja dulu tp begitu kerja disana saingannya s...
#   3. kabur yukkkkkk info info 🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  10%|▉         | 220/2226 [01:09<11:33,  2.89teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 220 (9.9%)
#   - Total belum berlabel: 2006
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 220/2226 (9.9%)
#
#
# ==================================================
# 🔖 BATCH 12/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Plissss doain aku yaaaaaa untuk bisa pake #kaburaj...
#   2. kasih clip 2 detik yang bilang "don't care" bagus ...
#   3. berita korupsi hampir setiap hari,bakal jadi negar...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  11%|█         | 240/2226 [01:11<08:57,  3.70teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 240 (10.8%)
#   - Total belum berlabel: 1986
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 240/2226 (10.8%)
#
#
# ==================================================
# 🔖 BATCH 13/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. tapi aku ttp kabur ke spanyol🤭
#   2. iyaa siapppp bapak si paling nasionalisme
# kami mah...
#   3. syarat pindah negara
# 1 jago bahasa asing
# 2 puny du...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  12%|█▏        | 260/2226 [01:15<07:59,  4.10teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 260 (11.7%)
#   - Total belum berlabel: 1966
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 260/2226 (11.7%)
#
#
# ==================================================
# 🔖 BATCH 14/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kabur ke meksiko💀
#   2. Urusin ajah noh yg korupsi dan hukum 🐊🦍💦
#   3. sana sana biar gua kesempatan di sini makin banyak
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 280/2226 [01:21<08:35,  3.78teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 280 (12.6%)
#   - Total belum berlabel: 1946
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 280/2226 (12.6%)
#
#
# ==================================================
# 🔖 BATCH 15/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Nasionalisme pejabat hanya sekedar tentang isi per...
#   2. semua orang indo kalo sukses pasti pindah negara, ...
#   3. trend yang sayaa suka
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 300/2226 [01:23<06:47,  4.72teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 300 (13.5%)
#   - Total belum berlabel: 1926
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 300/2226 (13.5%)
#
#
# ==================================================
# 🔖 BATCH 16/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lagi berusaha untuk kabur semoga berhasil☺️
#   2. kak trus kami harus gimana ini udah -+50 lo surat ...
#   3. soon... after I meet my future husband 🙏🤭
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  14%|█▍        | 320/2226 [01:25<05:35,  5.68teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 320 (14.4%)
#   - Total belum berlabel: 1906
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 320/2226 (14.4%)
#
#
# ==================================================
# 🔖 BATCH 17/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lucu bgt editannya😂
#   2. keluar negeri woee keluar. awalnya berat tp nnti b...
#   3. tinggalkan indonesia
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  15%|█▌        | 340/2226 [01:29<05:48,  5.41teks/s]
# ✅ Respons diterima (157 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - netral: 9x (45.0%)
#   - negatif: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 340 (15.3%)
#   - Total belum berlabel: 1886
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 340/2226 (15.3%)
#
#
# ==================================================
# 🔖 BATCH 18/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Gak nyesel kabur ke jepang ternyata lebih enak, yu...
#   2. mau ke singapore ajaa
#   3. bener bgt nihh kak vin🙏🙏🙏menurut pandanganku anak ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  16%|█▌        | 360/2226 [01:40<09:15,  3.36teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 360 (16.2%)
#   - Total belum berlabel: 1866
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 360/2226 (16.2%)
#
#
# ==================================================
# 🔖 BATCH 19/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Ikutan dong....
# Saya sdh capek dinegeri ini, kita ...
#   2. rasa nasionalisme?gwe buang tuh jauh² dripada kelu...
#   3. tutor dong bg
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  17%|█▋        | 380/2226 [01:42<07:12,  4.27teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 380 (17.1%)
#   - Total belum berlabel: 1846
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 380/2226 (17.1%)
#
#
# ==================================================
# 🔖 BATCH 20/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. dia meragukan jiwa nasionalisme yg pindah ke luar ...
#   2. gua kalo ga mager belajar bahasa sama kalcer shock...
#   3. siapa suruh pemerintah korup😂
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  18%|█▊        | 400/2226 [01:43<05:49,  5.22teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 400 (18.0%)
#   - Total belum berlabel: 1826
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 400/2226 (18.0%)
#
#
# ==================================================
# 🔖 BATCH 21/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Aku tim #kaburajadulu sudah setahun kabur gegara g...
#   2. tai loker Indonesia susah, banyak bet persyaratan,...
#   3. seneng w liat nya 👍
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  19%|█▉        | 420/2226 [01:47<05:50,  5.16teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 5x (25.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 420 (18.9%)
#   - Total belum berlabel: 1806
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 420/2226 (18.9%)
#
#
# ==================================================
# 🔖 BATCH 22/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. LH Kan gara gara lu orang orang pada pindah kocak🗿...
#   2. info dong kerja di jepang. siap terbang
#   3. yok semuanya pindahhh😁
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  20%|█▉        | 440/2226 [01:50<04:57,  5.99teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 440 (19.8%)
#   - Total belum berlabel: 1786
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 440/2226 (19.8%)
#
#
# ==================================================
# 🔖 BATCH 23/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Wes gpp, bebas awuren ae lah pak 🤣
#   2. indo=hama
#   3. kenapa yang gk di tanya nasionalisme itu pejabat n...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  21%|██        | 460/2226 [01:53<04:46,  6.16teks/s]
# ✅ Respons diterima (151 karakter)
# 🏷️ Label terdeteksi:
#   - netral: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 460 (20.7%)
#   - Total belum berlabel: 1766
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 460/2226 (20.7%)
#
#
# ==================================================
# 🔖 BATCH 24/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kalo GK punya suami dan anak,q udah kabur kaleee😌😌...
#   2. bro lupa dengan bapak Prabowo presiden kita saat i...
#   3. ga tau ap itu nasionalisme,, 😆😆,, cinta negara sen...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 480/2226 [01:56<04:53,  5.95teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 480 (21.6%)
#   - Total belum berlabel: 1746
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 480/2226 (21.6%)
#
#
# ==================================================
# 🔖 BATCH 25/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pindah aja sekalian malah bagus 👍👍
#   2. kalo gua Amerika Serikat enak🗿
#   3. luar negeri lbh menjamin mulai dunia krj seperti n...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 500/2226 [01:58<04:05,  7.04teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - negatif: 5x (25.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 500 (22.5%)
#   - Total belum berlabel: 1726
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 500/2226 (22.5%)
#
#
# ==================================================
# 🔖 BATCH 26/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. dulu pak prabowo yg sangat nasionalis pernah meran...
#   2. hidup adalah pilihah👍semangat sodara2👏
#   3. #kaburajadulu bismillah norwegia
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  23%|██▎       | 520/2226 [02:01<04:08,  6.86teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 520 (23.4%)
#   - Total belum berlabel: 1706
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 520/2226 (23.4%)
#
#
# ==================================================
# 🔖 BATCH 27/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gas ke Jepang 🗿
#   2. di kampung gw lulusan sarjana kaga diterima di ker...
#   3. mending tidur aja dulu 🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  24%|██▍       | 540/2226 [02:10<06:36,  4.25teks/s]
# ✅ Respons diterima (149 karakter)
# 🏷️ Label terdeteksi:
#   - netral: 10x (50.0%)
#   - negatif: 6x (30.0%)
#   - positif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 540 (24.3%)
#   - Total belum berlabel: 1686
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 540/2226 (24.3%)
#
#
# ==================================================
# 🔖 BATCH 28/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ayo nungguin kliann ini
#   2. aq juga ragu sama bapak
#   3. nasionalisme gue aja ilang setelah lihat pendidika...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  25%|██▌       | 560/2226 [02:12<05:20,  5.20teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 4x (20.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 560 (25.2%)
#   - Total belum berlabel: 1666
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 560/2226 (25.2%)
#
#
# ==================================================
# 🔖 BATCH 29/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gen z benar2 pemberontak
#   2. udh di Turki males di Indonesia udh bosen🙏
# #Kabura...
#   3. banyak milih pindah 😁
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  26%|██▌       | 580/2226 [02:13<04:20,  6.32teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 580 (26.1%)
#   - Total belum berlabel: 1646
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 580/2226 (26.1%)
#
#
# ==================================================
# 🔖 BATCH 30/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. doin akuu ya kak lulus sekolah langsung kursus spa...
#   2. seimbang tinggal di negara maju biaya hidup tinggi...
#   3. yg mau jadiin ak warga negaranya saya mau bgt..gpp...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  27%|██▋       | 600/2226 [02:17<04:27,  6.07teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 600 (27.0%)
#   - Total belum berlabel: 1626
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 600/2226 (27.0%)
#
#
# ==================================================
# 🔖 BATCH 31/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. 😂😂bahlil is bahlul
#   2. justru kami yang meragukan pekerjaan bapak😂😂😂😂😂😂
#   3. nabung sehari 50k kira2 berapa bulan ya ke 50jt
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  28%|██▊       | 620/2226 [02:24<06:03,  4.41teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 620 (27.9%)
#   - Total belum berlabel: 1606
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 620/2226 (27.9%)
#
#
# ==================================================
# 🔖 BATCH 32/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kaburajaduluy
#   2. ini tuh ibarat kayak cari pasangan,kalo pasangan k...
#   3. sebenarnya makin untung banyak, soalnya saingan ke...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  29%|██▉       | 640/2226 [02:30<06:21,  4.16teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 640 (28.8%)
#   - Total belum berlabel: 1586
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 640/2226 (28.8%)
#
#
# ==================================================
# 🔖 BATCH 33/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gas taun depan 🔥🔥
#   2. bang jepang kok kota bukanya negara ya
#   3. udah kaburr ini udah 3 thn 🤣🤣
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  30%|██▉       | 660/2226 [02:32<05:14,  4.98teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - netral: 5x (25.0%)
#   - negatif: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 660 (29.6%)
#   - Total belum berlabel: 1566
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 660/2226 (29.6%)
#
#
# ==================================================
# 🔖 BATCH 34/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. semngt
#   2. sejak kapan indonesia diterapkan nasionalisme? org...
#   3. yang merampok uang rakyat itu yang perlu diragukan...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███       | 680/2226 [02:41<07:19,  3.52teks/s]
# ✅ Respons diterima (276 karakter)
# ⚠️ Jumlah label (19) tidak sesuai dengan jumlah teks (20)
# ➕ Menambah hingga 20 label dengan 'negatif'
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 680 (30.5%)
#   - Total belum berlabel: 1546
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 680/2226 (30.5%)
#
#
# ==================================================
# 🔖 BATCH 35/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Jadi mikey disana kayanya seru
#   2. ketika smpi di jepang.
# omaedareda dokokara kokoden...
#   3. ramalan the Simpsons peta Indonesia 💀💀
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███▏      | 700/2226 [02:47<07:11,  3.54teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 5x (25.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 700 (31.4%)
#   - Total belum berlabel: 1526
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 700/2226 (31.4%)
#
#
# ==================================================
# 🔖 BATCH 36/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. APA KABAR DENGAN OKNUM PEJABAT YG KORUPSI APA MERE...
#   2. orang nda makan nasionalisme pak 🤣.
# lagian kami lo...
#   3. nasionalisme ya?Bahlil dan seluruh jajaran pemerin...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  32%|███▏      | 720/2226 [02:49<05:32,  4.53teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - netral: 7x (35.0%)
#   - negatif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 720 (32.3%)
#   - Total belum berlabel: 1506
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 720/2226 (32.3%)
#
#
# ==================================================
# 🔖 BATCH 37/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bismillah DV USku 2025 lolos JD 2026 go to US..Aam...
#   2. mau duit kok kabur,usaha dong usaha, kerjaan yang ...
#   3. Tutup telinga kita seperti pemerintah tutup teling...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  33%|███▎      | 740/2226 [02:51<04:50,  5.11teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - netral: 7x (35.0%)
#   - positif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 740 (33.2%)
#   - Total belum berlabel: 1486
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 740/2226 (33.2%)
#
#
# ==================================================
# 🔖 BATCH 38/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Aku siihh yeess #kabur aja dulu 🏃‍♀️🏃‍♀️
#   2. yang dapet beasiswa, yang cerdas, dan yang diberi ...
#   3. buat apa bertahan di dalam negri
# klau ada yang mat...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  34%|███▍      | 760/2226 [02:56<05:10,  4.73teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 760 (34.1%)
#   - Total belum berlabel: 1466
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 760/2226 (34.1%)
#
#
# ==================================================
# 🔖 BATCH 39/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @haechan @doyandimsum ki wong2 gpngen kabur kah
#   2. urus dulu tu koruptor
#   3. wkwk
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  35%|███▌      | 780/2226 [03:00<04:58,  4.85teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 780 (35.0%)
#   - Total belum berlabel: 1446
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 780/2226 (35.0%)
#
#
# ==================================================
# 🔖 BATCH 40/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Sebenarnya mah orang2 Indonesia itu punya banyak p...
#   2. saya meragukan kerja bapak gimana 🤔
#   3. WKWKWKWKKWK GUE SUKA GAYA LO🤣🤣🫵🏻🫵🏻
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  36%|███▌      | 800/2226 [03:02<04:00,  5.93teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 800 (35.9%)
#   - Total belum berlabel: 1426
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 800/2226 (35.9%)
#
#
# ==================================================
# 🔖 BATCH 41/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. syarat banyak
# gaji dikit
# #kaburajadulu
#   2. tapi rata rata yg merantau di luar negri hidup nya...
#   3. kabur tinggal kabur
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  37%|███▋      | 820/2226 [03:04<03:38,  6.44teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 820 (36.8%)
#   - Total belum berlabel: 1406
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 820/2226 (36.8%)
#
#
# ==================================================
# 🔖 BATCH 42/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. you'd never weaken your nationalism when you go ab...
#   2. "saya cinta indo Nesia " tapi dengan cinta jg ngk ...
#   3. ke jepang yok spaa mau ikut?
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  38%|███▊      | 840/2226 [03:06<03:04,  7.50teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 840 (37.7%)
#   - Total belum berlabel: 1386
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 840/2226 (37.7%)
#
#
# ==================================================
# 🔖 BATCH 43/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. makin di persulit ini mah ke LN 🙄🙄
#   2. Lah nanyain rakyat soal nasionalisme..lah pejabat ...
#   3. AAAA
# I NEED LONDON NOWWWW
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  39%|███▊      | 860/2226 [03:13<04:24,  5.16teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 860 (38.6%)
#   - Total belum berlabel: 1366
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 860/2226 (38.6%)
#
#
# ==================================================
# 🔖 BATCH 44/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. abaikan omongan si bahlil percuma tidak bisa membu...
#   2. memangnya pejabat nasionalisme ??? 🤪🤪🤪
#   3. kakak,tim apa nih?
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|███▉      | 880/2226 [03:14<03:38,  6.17teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 6x (30.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 880 (39.5%)
#   - Total belum berlabel: 1346
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 880/2226 (39.5%)
#
#
# ==================================================
# 🔖 BATCH 45/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. apakah yg korup itu termasuk nasionalisme?????? bp...
#   2. Nasionalisme = pro koruptor
#   3. lahk kok ngatur dia seenak nya aja 😏
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|████      | 900/2226 [03:16<03:02,  7.25teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 900 (40.4%)
#   - Total belum berlabel: 1326
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 900/2226 (40.4%)
#
#
# ==================================================
# 🔖 BATCH 46/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bawa aku kabur k luar negri kak aku jg g betah d k...
#   2. Saya pernah dengar kalimat " Jangan tanyakan apa y...
#   3. ke jepang di bayar 469 juta
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  41%|████▏     | 920/2226 [03:19<02:59,  7.28teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - netral: 6x (30.0%)
#   - positif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 920 (41.3%)
#   - Total belum berlabel: 1306
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 920/2226 (41.3%)
#
#
# ==================================================
# 🔖 BATCH 47/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. alhamdulillah sudah #kaburajadulu di Taiwan, tahun...
#   2. aku malah disupport ortu untuk keluar negeri,tapi ...
#   3. kok koruptor ngk di bilangin gni...? bukany sama m...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  42%|████▏     | 940/2226 [03:20<02:35,  8.29teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 940 (42.2%)
#   - Total belum berlabel: 1286
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 940/2226 (42.2%)
#
#
# ==================================================
# 🔖 BATCH 48/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kita nasionalis pak, tpi klo ngandelin nasionalis ...
#   2. wkwk nasionalisme apaan jir gw malah pernah ngebay...
#   3. iyalah ke luar negeri di indo banyak tikus😂😂😂
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  43%|████▎     | 960/2226 [03:22<02:28,  8.51teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 960 (43.1%)
#   - Total belum berlabel: 1266
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 960/2226 (43.1%)
#
#
# ==================================================
# 🔖 BATCH 49/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. saya sangat cinta Indonesia tapi cinta saya bertep...
#   2. nasionalisme pas timnas main😁😁
#   3. AMIN ✨🙏
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  44%|████▍     | 980/2226 [04:08<15:44,  1.32teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 980 (44.0%)
#   - Total belum berlabel: 1246
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 980/2226 (44.0%)
#
#
# ==================================================
# 🔖 BATCH 50/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. susah2 si wowo ksh mkn gratis malah kabur🤣
#   2. kusebut tampan dan berani😹
#   3. Sudah aku lakukan!!
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  45%|████▍     | 1000/2226 [04:10<11:31,  1.77teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1000 (44.9%)
#   - Total belum berlabel: 1226
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 1000/2226 (44.9%)
#
#
# ==================================================
# 🔖 BATCH 51/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pemerintah nya keren
#   2. EMANG ELU YG KASIH MAKAN APA?
#   3. lah, saya meragukan kinerja pak bahlil
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  46%|████▌     | 1020/2226 [04:11<08:21,  2.40teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1020 (45.8%)
#   - Total belum berlabel: 1206
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 1020/2226 (45.8%)
#
#
# ==================================================
# 🔖 BATCH 52/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mau ke thailand🥺
#   2. percuma punya nasionalisme tinggi,tpi negara ga me...
#   3. 23 thn di luar negeri bagi saya tetap masa tua yg ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  47%|████▋     | 1040/2226 [04:17<07:33,  2.61teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1040 (46.7%)
#   - Total belum berlabel: 1186
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 1040/2226 (46.7%)
#
#
# ==================================================
# 🔖 BATCH 53/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lah di negeri sendiri aja gk makmur pak bnyk pejab...
#   2. ayo kita ke jepang ...
#   3. di indo nganggur
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  48%|████▊     | 1060/2226 [04:19<05:39,  3.43teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - positif: 5x (25.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1060 (47.6%)
#   - Total belum berlabel: 1166
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 1060/2226 (47.6%)
#
#
# ==================================================
# 🔖 BATCH 54/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ga jg pk kami cr mata pencaharian tk bertahan hidu...
#   2. kalau mau kerja yah ada orang dalam kecuali kita p...
#   3. Capekkk ah sma negara sendiri😫
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▊     | 1080/2226 [04:25<05:31,  3.46teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1080 (48.5%)
#   - Total belum berlabel: 1146
# 💾 Backup dibuat: label-data/progress_sentiment_1_to_6.csv.bak
# 💾 Progress tersimpan: 1080/2226 (48.5%)
#
#
# ==================================================
# 🔖 BATCH 55/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. nasionalisme itu sendiri tumbuh dari apa? Indonesi...
#   2. Sudah tau kan negara mana yg nyusul afrika sehabis...
#   3. 😅😅 selamat berjuang dan bahagia, pulang saat pensi...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▉     | 1100/2226 [04:26<04:19,  4.34teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1100 (49.4%)
#   - Total belum berlabel: 1126
# ...
#
#
# ==================================================
# 🔖 BATCH 95/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yaa udh si aku juga mau ikut kaka kerja di jepang🤪...
#   2. saya juga meragukan pak Bahlil,,,
#   3. ini lah INDONESIA...kerjanya serius.. gajinya berc...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  85%|████████▌ | 1900/2226 [05:56<00:49,  6.63teks/s]
# ✅ Respons diterima (164 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1900 (85.4%)
#   - Total belum berlabel: 326
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 1900/2226 (85.4%)
#
#
# ==================================================
# 🔖 BATCH 96/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. jangan bawak bawak nama aku bg
# 😂😂😂
#   2. Pengalaman hidupku emang bener sih d luar negri te...
#   3. pengen kabur juga donggg
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  86%|████████▋ | 1920/2226 [06:01<00:54,  5.65teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1920 (86.3%)
#   - Total belum berlabel: 306
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 1920/2226 (86.3%)
#
#
# ==================================================
# 🔖 BATCH 97/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. saya juga mau pindah pak😁
#   2. intinya gini, negara aja bodoamat masa kita gak bo...
#   3. @si manis 🍬 one day ya
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  87%|████████▋ | 1940/2226 [06:03<00:42,  6.65teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1940 (87.2%)
#   - Total belum berlabel: 286
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 1940/2226 (87.2%)
#
#
# ==================================================
# 🔖 BATCH 98/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. trus mamak bapak gw kemanain
#   2. klau pemerintah nya betul..mustahil rakyat mk pind...
#   3. bapk anaknya emang di indonesia?☺️
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  88%|████████▊ | 1960/2226 [06:05<00:38,  6.95teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1960 (88.1%)
#   - Total belum berlabel: 266
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 1960/2226 (88.1%)
#
#
# ==================================================
# 🔖 BATCH 99/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gw ke Rusia, kalian ke mana? 😁
#   2. punya jabatan...jd bicra bgtu.
#   3. dulu waktu sd pernah di kasih tau guru.. baca dulu...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  89%|████████▉ | 1980/2226 [06:08<00:35,  6.95teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 1980 (88.9%)
#   - Total belum berlabel: 246
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 1980/2226 (88.9%)
#
#
# ==================================================
# 🔖 BATCH 100/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. terus kalo soal yg #percumalaporpolisi, bapak mera...
#   2. kalau saya punya uang milyaran,saya juga pasti mil...
#   3. seru yaaa
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  90%|████████▉ | 2000/2226 [06:11<00:31,  7.27teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2000 (89.8%)
#   - Total belum berlabel: 226
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2000/2226 (89.8%)
#
#
# ==================================================
# 🔖 BATCH 101/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Bang bahas kasus Sekolah MAN 2 kota bekasi bang,mu...
#   2. trus bisa jamin untuk orng2 indonesia dpt pekerjaa...
#   3. yaudh si yg gamau ikutan, nikmatin aja hidup di in...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  91%|█████████ | 2020/2226 [06:13<00:26,  7.82teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2020 (90.7%)
#   - Total belum berlabel: 206
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2020/2226 (90.7%)
#
#
# ==================================================
# 🔖 BATCH 102/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. penting kch nasionalisme skrng ? 🤣
#   2. Los ra urus!
#   3. kita d luar negeri cuma kerja pak bukn korups*
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  92%|█████████▏| 2040/2226 [06:14<00:21,  8.71teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2040 (91.6%)
#   - Total belum berlabel: 186
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2040/2226 (91.6%)
#
#
# ==================================================
# 🔖 BATCH 103/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bahlil b nya apa bahlul
#   2. aku tahun depan disuruh suami pindah jepang ikut d...
#   3. pengen kerja di luar negri
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2060/2226 [06:18<00:23,  7.13teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2060 (92.5%)
#   - Total belum berlabel: 166
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2060/2226 (92.5%)
#
#
# ==================================================
# 🔖 BATCH 104/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. aku udah kabur, kalian kapan 😁
#   2. hanya ada 2 kelompok yg bisa hidup nyaman di konoh...
#   3. sii bahlil nih ngomong doang tnpa ngasih solusi .
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2080/2226 [06:20<00:18,  8.05teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2080 (93.4%)
#   - Total belum berlabel: 146
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2080/2226 (93.4%)
#
#
# ==================================================
# 🔖 BATCH 105/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ga sabar mau post begini
#   2. akankah akan terjadi lagi abad kekosongan indonesi...
#   3. semoga aku bisa nyusul kak.
# bismillah 2027
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  94%|█████████▍| 2100/2226 [06:22<00:14,  8.61teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2100 (94.3%)
#   - Total belum berlabel: 126
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2100/2226 (94.3%)
#
#
# ==================================================
# 🔖 BATCH 106/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ini si bahlil dari kemarin2 bikin gedeug gua sumpa...
#   2. doain bang lulus sma langsung pngnn ke jepangg
#   3. kamu meragukan nasionalisme kami?
# kamu meragukan k...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  95%|█████████▌| 2120/2226 [06:27<00:15,  6.71teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2120 (95.2%)
#   - Total belum berlabel: 106
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2120/2226 (95.2%)
#
#
# ==================================================
# 🔖 BATCH 107/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gass kk
#   2. gen Z kok ditantang, ya makin semangat lah kita 🔥🔥...
#   3. pemerintah shibal
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  96%|█████████▌| 2140/2226 [06:28<00:11,  7.67teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2140 (96.1%)
#   - Total belum berlabel: 86
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2140/2226 (96.1%)
#
#
# ==================================================
# 🔖 BATCH 108/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bicara nasionalisme tapi anda sendiri menjabat han...
#   2. kalo ada duit lebih banyak mah aku juga bakal pind...
#   3. @BUKAN GALIH gas kabur
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  97%|█████████▋| 2160/2226 [06:30<00:07,  8.74teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2160 (97.0%)
#   - Total belum berlabel: 66
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2160/2226 (97.0%)
#
#
# ==================================================
# 🔖 BATCH 109/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. TETAP KBUR AJ DLU
#   2. klo mnrut gw sih enak nya di luar negri krna
# 1.lap...
#   3. Yg punya adik yg duduk di bangku SMA. Suru aja mer...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  98%|█████████▊| 2180/2226 [06:32<00:05,  8.54teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2180 (97.9%)
#   - Total belum berlabel: 46
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2180/2226 (97.9%)
#
#
# ==================================================
# 🔖 BATCH 110/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @panggil KY~aja@#
#   2. info loker luar negri dong
#   3. lebih meragukan kejujuran pemerintah dan hukum neg...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  99%|█████████▉| 2200/2226 [06:36<00:03,  7.10teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - netral: 6x (30.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2200 (98.8%)
#   - Total belum berlabel: 26
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2200/2226 (98.8%)
#
#
# ==================================================
# 🔖 BATCH 111/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. america sini kalian kapann😂
#   2. manifesting 2026 juga tinggal dan kerja di luar ne...
#   3. mana yg nasionalisme kita yg kerja keluar negeri a...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|█████████▉| 2220/2226 [06:40<00:00,  6.74teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2220 (99.7%)
#   - Total belum berlabel: 6
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2220/2226 (99.7%)
#
#
# ==================================================
# 🔖 BATCH 112/112 (6 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. infokan joki skripsi 😹😹😹 udah joki kena plagiat la...
#   2. otw nyusul setelah pendidikan selesai disini 😻
#   3. ngomong doang kabur dulu, tapi gk kabur2😂
#   ... dan 3 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|██████████| 2226/2226 [06:44<00:00,  5.50teks/s]
# ✅ Respons diterima (46 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 3x (50.0%)
#   - positif: 2x (33.3%)
#   - netral: 1x (16.7%)
# ✅ 6 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2226
#   - Total berlabel: 2226 (100.0%)
#   - Total belum berlabel: 0
# 💾 Backup dibuat: label-data/progress_sentiment_2_to_6.csv.bak
# 💾 Progress tersimpan: 2226/2226 (100.0%)
#
# 📊 STATISTIK AKHIR:
#   - Total record: 2226
#   - Total teks unik: 2226
#   - Record berlabel: 2226 (100.0%)
#   - Record belum berlabel: 0 (0.0%)
#   - Teks unik berlabel: 2226 (100.0%)
#
# 💾 Menyimpan hasil akhir...
# 🎉 PROSES SELESAI! Hasil disimpan di label-data/labeled_sentiment_2_to_6.csv
#
# ⏱️ Total waktu eksekusi: 6.7 menit
# 📊 Record berlabel: 2226/2226 (100.0%)
# 📊 Teks unik berlabel: 2226/2226 (100.0%)
#
# ============================================================
# SELESAI MEMPROSES CHUNK 2/6
# ============================================================

# %%
for i in range(3, 5):  # proses per 2 chunk
    # Update konfigurasi untuk chunk ini
    INPUT_CSV = f'full-data/result/chunks/chunk_{i}_of_6.csv'
    PROGRESS_CSV = f'label-data/progress_sentiment_{i}_to_6.csv'
    OUTPUT_CSV = f'label-data/labeled_sentiment_{i}_to_6.csv'
    
    # Panggil fungsi main
    print(f"\n\n{'='*60}")
    print(f"MEMULAI PROSES UNTUK CHUNK {i}/6")
    print(f"{'='*60}\n")
    
    # Jalankan proses labeling untuk chunk ini
    main()
    
    print(f"\n{'='*60}")
    print(f"SELESAI MEMPROSES CHUNK {i}/6")
    print(f"{'='*60}\n\n")
# Out:
# ============================================================
# MEMULAI PROSES UNTUK CHUNK 3/6
# ============================================================
#
#
# ==================================================
# 🚀 MEMULAI PROSES LABELING SENTIMENT #KABURAJADULU
# ==================================================
# 📊 Memuat dataset dari full-data/result/chunks/chunk_3_of_6.csv...
# ✅ Dataset berhasil dimuat. Total record: 2225
# 🆕 Membuat file progress baru...
#
# 📊 STATISTIK DATASET:
#   - Total record: 2225
#   - Total teks unik: 2225
#   - Record berlabel: 0 (0.0%)
#   - Record belum berlabel: 2225 (100.0%)
#   - Teks unik belum berlabel: 2225
# 📋 Statistik data yang belum dilabel:
#   - Total record belum berlabel: 2225/2225
#   - Teks unik belum berlabel: 2225
# 🧮 Membagi 2225 teks unik menjadi 112 batch
# 🚀 Progress Labeling:   0%|          | 0/2225 [00:00<?, ?teks/s]
# ==================================================
# 🔖 BATCH 1/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kabur ya kabur aja🗿
#   2. bismilllah ke jepang kerja atau kuliah
#   3. info pindah negara donk bolo..dh capek nih sm pera...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   1%|          | 20/2225 [00:04<08:14,  4.46teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 12x (60.0%)
#   - negatif: 4x (20.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 20 (0.9%)
#   - Total belum berlabel: 2205
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 20/2225 (0.9%)
#
#
# ==================================================
# 🔖 BATCH 2/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Ke 1 gaji kecil ke 2 peraturn perusahaan udah gak ...
#   2. saya cinta Indonesia karena alamnya
#   3. 2o26 insyaallah ikut juga , jerman i am coming
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   2%|▏         | 40/2225 [00:06<05:25,  6.72teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 40 (1.8%)
#   - Total belum berlabel: 2185
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 40/2225 (1.8%)
#
#
# ==================================================
# 🔖 BATCH 3/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mana tunjangan ibu gua dipotong lagi co
#   2. klo syarat pindah gampang sy pingin secepatnya pin...
#   3. nasionalisme apaanlah ,ngorong
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   3%|▎         | 60/2225 [00:42<33:01,  1.09teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 60 (2.7%)
#   - Total belum berlabel: 2165
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 60/2225 (2.7%)
#
#
# ==================================================
# 🔖 BATCH 4/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bismillah Agoda Malaysia 😁 #KaburAjaTerus
#   2. dia mah enak anjj dia udh kayak udh ada jabatan ud...
#   3. astagfirullah lagi bulan puasa lagi GK mau gk suka...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▎         | 80/2225 [00:44<21:06,  1.69teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 80 (3.6%)
#   - Total belum berlabel: 2145
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 80/2225 (3.6%)
#
#
# ==================================================
# 🔖 BATCH 5/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Yang kaya dan kenyang perutnya cuman PEJABAT nya R...
#   2. Olahraga di byon combat sma ni org yg pake jas bol...
#   3. otw
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▍         | 100/2225 [00:46<14:21,  2.47teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 100 (4.5%)
#   - Total belum berlabel: 2125
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 100/2225 (4.5%)
#
#
# ==================================================
# 🔖 BATCH 6/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kak tolong blg sma HRD jgn banyak x syarat kak smp...
#   2. kerja rodi di sana😂
#   3. mau bgt gimana caranya bisa keluar negeri 😭😭😭
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   5%|▌         | 120/2225 [00:50<12:08,  2.89teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 120 (5.4%)
#   - Total belum berlabel: 2105
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 120/2225 (5.4%)
#
#
# ==================================================
# 🔖 BATCH 7/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. indon yg kontra dgn kaburajadulu itu indon yg sdm ...
#   2. kalian yg masih muda cari pengalaman yg banyak dim...
#   3. Tanyakan sama diri bpk sendiri apa yg udh bpk perb...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   6%|▋         | 140/2225 [00:55<10:50,  3.21teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 7x (35.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 140 (6.3%)
#   - Total belum berlabel: 2085
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 140/2225 (6.3%)
#
#
# ==================================================
# 🔖 BATCH 8/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. rakyatnya aja gk di hargain 🗿
#   2. skrg kayak lebih dipersulit lagi apa2nya dikonoha....
#   3. gacoorr😂 @انندا نور عينى
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   7%|▋         | 160/2225 [00:58<08:47,  3.91teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 160 (7.2%)
#   - Total belum berlabel: 2065
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 160/2225 (7.2%)
#
#
# ==================================================
# 🔖 BATCH 9/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Gue Malah Meragukan Kerja Bahlil Dipemerintahan.😎
#   2. @hala Madrid:"Terlahir disini tanpa diminta,menjal...
#   3. Saya juga meragukan kinerja dan kebijakan bapak di...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   8%|▊         | 180/2225 [01:03<08:25,  4.05teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 180 (8.1%)
#   - Total belum berlabel: 2045
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 180/2225 (8.1%)
#
#
# ==================================================
# 🔖 BATCH 10/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Semoga bisa ke luar negri ya Allah pengen bNget ke...
#   2. biar apa?BIARINNN 🤭😛
#   3. saya malah meragukan nasionalisme"nya pejabat yg d...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   9%|▉         | 200/2225 [01:06<07:33,  4.47teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 200 (9.0%)
#   - Total belum berlabel: 2025
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 200/2225 (9.0%)
#
#
# ==================================================
# 🔖 BATCH 11/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Wajah villainnya ketara banget cuy🗿
#   2. Bahlul Atau Bahlil adalah penyakit buat negara bua...
#   3. giliran kena masalah di luar negri bkin vidio mnta...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  10%|▉         | 220/2225 [01:08<06:00,  5.56teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 220 (9.9%)
#   - Total belum berlabel: 2005
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 220/2225 (9.9%)
#
#
# ==================================================
# 🔖 BATCH 12/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. saya lebih Memilih Pindah mbak. alasan Pertama Kre...
#   2. itu yang ngomong pertama gak pernah ngerasin kayan...
#   3. wkwkwkwkwkwk😭
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  11%|█         | 240/2225 [01:09<04:54,  6.75teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 240 (10.8%)
#   - Total belum berlabel: 1985
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 240/2225 (10.8%)
#
#
# ==================================================
# 🔖 BATCH 13/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. heleehh nyari kerja disini susah pak banyak syarat...
#   2. 1.kebanyakan kriteria buat lamar kerja
# 2.gaji pun ...
#   3. Jangan ditanya jiwa nasionalisme kami. Tapi beda k...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  12%|█▏        | 260/2225 [01:13<05:20,  6.13teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 260 (11.7%)
#   - Total belum berlabel: 1965
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 260/2225 (11.7%)
#
#
# ==================================================
# 🔖 BATCH 14/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. tim bola ambil dari belanda, yg mau kerja ke luar ...
#   2. jika anda merasa nasionalisme tolong sejahterakan ...
#   3. Dia ngomong nasionalisme 🤣🤣
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 280/2225 [01:15<04:31,  7.15teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 5x (25.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 280 (12.6%)
#   - Total belum berlabel: 1945
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 280/2225 (12.6%)
#
#
# ==================================================
# 🔖 BATCH 15/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Los ke lek✌🔥
#   2. bg gua nunggu² lu dri kemarin buat bahas ginian😅
#   3. gw demen ne yg seperti ini
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 300/2225 [01:18<04:38,  6.90teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 300 (13.5%)
#   - Total belum berlabel: 1925
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 300/2225 (13.5%)
#
#
# ==================================================
# 🔖 BATCH 16/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. udah 2 taun kabur nih🤭😭😭
#   2. capekkk..... #kaburajadulu😹
#   3. ikut kaburaja dulu
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  14%|█▍        | 320/2225 [01:22<05:08,  6.18teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 320 (14.4%)
#   - Total belum berlabel: 1905
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 320/2225 (14.4%)
#
#
# ==================================================
# 🔖 BATCH 17/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lah di sini tapi kalau ga dibantu sejahtera mah me...
#   2. pilihan yg ke2 nikmati aja di indo hidup ama mertu...
#   3. meragukan nasionalisme kami? kami meragukan anda!
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  15%|█▌        | 340/2225 [01:23<04:14,  7.41teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 340 (15.3%)
#   - Total belum berlabel: 1885
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 340/2225 (15.3%)
#
#
# ==================================================
# 🔖 BATCH 18/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. #kaburajadulu @NAMANYA SHALWA
#   2. me next
#   3. Doain gua berhasil ya guys…gua rencana lulus smk l...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  16%|█▌        | 360/2225 [01:29<05:27,  5.70teks/s]
# ✅ Respons diterima (150 karakter)
# 🏷️ Label terdeteksi:
#   - netral: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - negatif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 360 (16.2%)
#   - Total belum berlabel: 1865
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 360/2225 (16.2%)
#
#
# ==================================================
# 🔖 BATCH 19/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Menurut pendapat KAMI. " KAMI tdk meragukan Nasion...
#   2. negeri macam apa ni😭
#   3. asikk bang lu asikk😂😭
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  17%|█▋        | 380/2225 [01:31<04:40,  6.59teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 380 (17.1%)
#   - Total belum berlabel: 1845
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 380/2225 (17.1%)
#
#
# ==================================================
# 🔖 BATCH 20/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Klo mau pindah pindah aja gpp
# malah ngurangi saing...
#   2. di Indonesia karir ga menjamin masa depan apalagi ...
#   3. lah siapa peduli ya kak
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  18%|█▊        | 400/2225 [01:55<14:07,  2.15teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 12x (60.0%)
#   - negatif: 4x (20.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 400 (18.0%)
#   - Total belum berlabel: 1825
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 400/2225 (18.0%)
#
#
# ==================================================
# 🔖 BATCH 21/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Info harus gimana awalnya. Baru lulus tp bingung m...
#   2. bahlil lupa klo dulu prabowo juga pernah kabur ke ...
#   3. Kek gini d jadikan menteri,hadeh😂
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  19%|█▉        | 420/2225 [02:12<17:29,  1.72teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 420 (18.9%)
#   - Total belum berlabel: 1805
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 420/2225 (18.9%)
#
#
# ==================================================
# 🔖 BATCH 22/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. henya,,, hante 😂
#   2. org kita juga meragukan pemerintah
#   3. shiballl🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  20%|█▉        | 440/2225 [03:22<43:20,  1.46s/teks]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - positif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 440 (19.8%)
#   - Total belum berlabel: 1785
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 440/2225 (19.8%)
#
#
# ==================================================
# 🔖 BATCH 23/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. saya juga pingin kabur aja dulu pak🤣
#   2. kalo menurutku rezeki, kebahagiaan, cinta itu haru...
#   3. bukan tentang nasionalisme pak Bahlil tapi sistem ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  21%|██        | 460/2225 [03:23<30:41,  1.04s/teks]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 460 (20.7%)
#   - Total belum berlabel: 1765
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 460/2225 (20.7%)
#
#
# ==================================================
# 🔖 BATCH 24/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lah,berarti kite mah pindah krna "meragukan kinerj...
#   2. hidup iki bukan cumk ngurusin uang dan pkerjaan du...
#   3. yang ragu adalah pemerintah yang engga pro rakyat
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 480/2225 [03:27<22:59,  1.27teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 480 (21.6%)
#   - Total belum berlabel: 1745
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 480/2225 (21.6%)
#
#
# ==================================================
# 🔖 BATCH 25/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. tetap pada intinya
# beradalah ditempat dimana kamu ...
#   2. justru sebaliknya rakyat lah yang meragukan para p...
#   3. buset fyp gua full #kaburajadulu
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 500/2225 [03:41<21:52,  1.31teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 500 (22.5%)
#   - Total belum berlabel: 1725
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 500/2225 (22.5%)
#
#
# ==================================================
# 🔖 BATCH 26/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. #kaburajadulu ke swiss🗿
#   2. kabur aja dulu, nanti balik lagi
#   3. Umur 25 keatas di anggap lansia 🙏🏻
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  23%|██▎       | 520/2225 [04:00<23:20,  1.22teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 520 (23.4%)
#   - Total belum berlabel: 1705
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 520/2225 (23.4%)
#
#
# ==================================================
# 🔖 BATCH 27/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. diragukan nasionalisme sama pejabat yg korup
#   2. perkaya diri sendiri saja pak ga usah mikirin oran...
#   3. kalo nasionalisme,
# PEJABAT dan PARA APARAT2 NEGARA...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  24%|██▍       | 540/2225 [04:02<16:57,  1.66teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 540 (24.3%)
#   - Total belum berlabel: 1685
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 540/2225 (24.3%)
#
#
# ==================================================
# 🔖 BATCH 28/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. info job jepang bolo po korea opo ngendi wes sembi...
#   2. wkwkwkw gua mah selow ajah🤣🤣🤣
#   3. kalo menurut kamu gimana kak?
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  25%|██▌       | 560/2225 [04:21<19:19,  1.44teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 5x (25.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 560 (25.2%)
#   - Total belum berlabel: 1665
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 560/2225 (25.2%)
#
#
# ==================================================
# 🔖 BATCH 29/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kabur harus bawa hasil ya adek adek
#   2. 🤣🤣🤣 bagaimana dengan nasionalisme Wowo waktu kabur...
#   3. ada yang janji kerjaan 19 juta mana cuma ngomong d...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  26%|██▌       | 580/2225 [04:22<14:07,  1.94teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 580 (26.1%)
#   - Total belum berlabel: 1645
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 580/2225 (26.1%)
#
#
# ==================================================
# 🔖 BATCH 30/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Saya doakan anda warga Indonesia berjaya di luar n...
#   2. yang ortunya kaya, gih gpp mau #KaburAjaDulu cari ...
#   3. bukan masalah nasionalisme nya,tapi ekonominya,, k...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  27%|██▋       | 600/2225 [04:24<10:27,  2.59teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 600 (27.0%)
#   - Total belum berlabel: 1625
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 600/2225 (27.0%)
#
#
# ==================================================
# 🔖 BATCH 31/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. otw bikin paspor 😂😂
#   2. w aja berharap nanti anak anak ku berkarir di luar...
#   3. rakyat bayar pajak tp negara tdk bisa kasih lapang...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  28%|██▊       | 620/2225 [04:30<09:33,  2.80teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 620 (27.9%)
#   - Total belum berlabel: 1605
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 620/2225 (27.9%)
#
#
# ==================================================
# 🔖 BATCH 32/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bilang aja kalau banyak warga yg pindah yg gaji an...
#   2. nasionalisme? sejak kapan ada ?
#   3. ajakin gw kaburr😭🗿🗿🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  29%|██▉       | 640/2225 [04:39<10:07,  2.61teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - netral: 6x (30.0%)
#   - negatif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 640 (28.8%)
#   - Total belum berlabel: 1585
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 640/2225 (28.8%)
#
#
# ==================================================
# 🔖 BATCH 33/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Pengen nya sih kabur, tapi ga punya syarat yg cuku...
#   2. giliran di sandra di luar minta bantuan ngemis² ke...
#   3. itu yang pindah, meragukan karir mereka dinegeri k...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  30%|██▉       | 660/2225 [04:43<08:40,  3.01teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 660 (29.7%)
#   - Total belum berlabel: 1565
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 660/2225 (29.7%)
#
#
# ==================================================
# 🔖 BATCH 34/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. klo bisa sih mau pindah juga ke planet Mars
#   2. didalam negeri persyaratan kerja ditempat yang mem...
#   3. kak aku dari th 2016 di malaysia sejak lulus sekol...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███       | 680/2225 [04:44<06:33,  3.93teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 680 (30.6%)
#   - Total belum berlabel: 1545
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 680/2225 (30.6%)
#
#
# ==================================================
# 🔖 BATCH 35/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. jika pngurusan ke luar negeri tidak ribet, indones...
#   2. raisain dulu pak bahlil jangan cuma ngomog 🤣
#   3. mikirin nasionalisme kelaparan pak KLO negara g me...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███▏      | 700/2225 [04:46<05:05,  4.99teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 700 (31.5%)
#   - Total belum berlabel: 1525
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 700/2225 (31.5%)
#
#
# ==================================================
# 🔖 BATCH 36/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Tenang saja pak.. yg mau pindah kita doakan sukses...
#   2. WOWO SAJA DULU KABUR KE YORDANIA 😁😂😂😂
#   3. GAJI DIKIT PERSYARATAN MUSTAHIL🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  32%|███▏      | 720/2225 [04:48<04:14,  5.92teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 720 (32.4%)
#   - Total belum berlabel: 1505
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 720/2225 (32.4%)
#
#
# ==================================================
# 🔖 BATCH 37/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. cobain Bpk tanyain ini sm pejabat yg korup
#   2. I wish I could be there
#   3. dikira kita mengagumi nasionalisme bapak? 😂 tanya ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  33%|███▎      | 740/2225 [04:52<04:26,  5.57teks/s]
# ✅ Respons diterima (165 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 740 (33.3%)
#   - Total belum berlabel: 1485
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 740/2225 (33.3%)
#
#
# ==================================================
# 🔖 BATCH 38/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. sadar gasi pancasila yg ke unlock cuman sila perta...
#   2. #kaburajadulu ang ang ang ang 🤣
#   3. saya malah meragukan kerjaan bapak
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  34%|███▍      | 760/2225 [04:54<03:44,  6.52teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 12x (60.0%)
#   - negatif: 5x (25.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 760 (34.2%)
#   - Total belum berlabel: 1465
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 760/2225 (34.2%)
#
#
# ==================================================
# 🔖 BATCH 39/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gwe cepet fasih bhs. jepang gwe mah mending ke son...
#   2. cari kerja sesusah itu di negara sendiri 😌😌
#   3. emang Bahlil se nasionalis apa sih
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  35%|███▌      | 780/2225 [04:56<03:19,  7.25teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 780 (35.1%)
#   - Total belum berlabel: 1445
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 780/2225 (35.1%)
#
#
# ==================================================
# 🔖 BATCH 40/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. emang nasionalisme bisa bantu perekonomian kh
#   2. Tuhan bantulah aku😭
#   3. @sap🅰️🅰️ pindah arab
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  36%|███▌      | 800/2225 [04:57<02:48,  8.45teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 800 (36.0%)
#   - Total belum berlabel: 1425
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 800/2225 (36.0%)
#
#
# ==================================================
# 🔖 BATCH 41/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. sudah tim #kaburajadulu 😁😁
#   2. Tahun ini, bru mau pindah ke jerman pak... See ya ...
#   3. persyaratan loker susahnya selangit, gaji kecil, b...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  37%|███▋      | 820/2225 [05:07<05:25,  4.32teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 5x (25.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 820 (36.9%)
#   - Total belum berlabel: 1405
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 820/2225 (36.9%)
#
#
# ==================================================
# 🔖 BATCH 42/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yaallah, jepang
#   2. larangan adalah perintah😂
#   3. Orang pada kabur ke Jepang, aku malah balik ke Ind...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  38%|███▊      | 840/2225 [05:16<06:56,  3.33teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 840 (37.8%)
#   - Total belum berlabel: 1385
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 840/2225 (37.8%)
#
#
# ==================================================
# 🔖 BATCH 43/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mereka berani keluarin modal yg besar utk #kaburaj...
#   2. ngapain mikirin negara yg gk mikirin rakyat
#   3. saya juga meragukan pemerintah, kok gabisa bikin r...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  39%|███▊      | 860/2225 [05:22<06:39,  3.42teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 860 (38.7%)
#   - Total belum berlabel: 1365
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 860/2225 (38.7%)
#
#
# ==================================================
# 🔖 BATCH 44/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Bismillah😌#kaburajadulu
#   2. semoga bisa
#   3. klo masyarakat dah apatis sama pemerintah apapun o...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|███▉      | 880/2225 [05:24<05:24,  4.15teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 880 (39.6%)
#   - Total belum berlabel: 1345
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 880/2225 (39.6%)
#
#
# ==================================================
# 🔖 BATCH 45/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Bismillahirrohmanirrohim semoga aku juga bisa kun ...
#   2. 100rb 1bln ada lawan?😂
#   3. @🫀 ayok pindah ke jepang
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|████      | 900/2225 [05:36<07:39,  2.88teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 900 (40.4%)
#   - Total belum berlabel: 1325
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 900/2225 (40.4%)
#
#
# ==================================================
# 🔖 BATCH 46/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gak usah ragu pak. saya sendiri YAKIN saya tidak n...
#   2. memang sih di luar negeri gaji besar tapi pengelua...
#   3. sedihh banget indonesia ditinggalin sama orang pin...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  41%|████▏     | 920/2225 [05:43<07:35,  2.86teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - positif: 6x (30.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 920 (41.3%)
#   - Total belum berlabel: 1305
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 920/2225 (41.3%)
#
#
# ==================================================
# 🔖 BATCH 47/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Padahal saya tunggu tanggapan kak vina thd argumen...
#   2. saya malah nyesal nyoblos 02
#   3. lihat aja Indonesia sekarang,miris. Uda banyak yan...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  42%|████▏     | 940/2225 [05:48<06:40,  3.21teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 940 (42.2%)
#   - Total belum berlabel: 1285
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 940/2225 (42.2%)
#
#
# ==================================================
# 🔖 BATCH 48/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. salfok alisnya
#   2. mending pindah ke negara maju di banding tetep di ...
#   3. kabur aja dulu😏
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  43%|████▎     | 960/2225 [05:51<05:38,  3.74teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 960 (43.1%)
#   - Total belum berlabel: 1265
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 960/2225 (43.1%)
#
#
# ==================================================
# 🔖 BATCH 49/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gmna pun ceritanya aku bklan kaya gini jugaaa
#   2. Info dong cara pindahnya gimna
#   3. woyy menyala pak bahlil, makin semangat ini 🤣🔥🔥
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  44%|████▍     | 980/2225 [05:53<04:36,  4.50teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - netral: 6x (30.0%)
#   - negatif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 980 (44.0%)
#   - Total belum berlabel: 1245
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 980/2225 (44.0%)
#
#
# ==================================================
# 🔖 BATCH 50/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. minimal turunin dlu itu peraturan masuk kantornya,...
#   2. makanya AQ betah di Taiwan,,ogah pulang,,,
#   3. ngapain nasionalisme,yang ada mati kita di negara ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  45%|████▍     | 1000/2225 [05:57<04:09,  4.92teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1000 (44.9%)
#   - Total belum berlabel: 1225
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 1000/2225 (44.9%)
#
#
# ==================================================
# 🔖 BATCH 51/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. KASI SOLUSI ❌
# KASI KATA-KATA ✅🗿
#   2. Indonesia negara paling ribet
#   3. serah kalian lah, pada aneh" bae
# teman gw yg ke Fr...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  46%|████▌     | 1020/2225 [06:09<06:42,  2.99teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1020 (45.8%)
#   - Total belum berlabel: 1205
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 1020/2225 (45.8%)
#
#
# ==================================================
# 🔖 BATCH 52/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kerja klo telat potong gaji, tp klo overtime loyal...
#   2. please bentar lagi gw gede gw juga mau pindah
#   3. Denger suara orang ini kok jadi bahlul saya
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  47%|████▋     | 1040/2225 [06:34<11:52,  1.66teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1040 (46.7%)
#   - Total belum berlabel: 1185
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 1040/2225 (46.7%)
#
#
# ==================================================
# 🔖 BATCH 53/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yg dimaksud pindah aja dulu, itu pindah WNI ke WNA...
#   2. prabowo juga kabur ke yordania. dia pencetusnya.
#   3. kita jg meragukan nasionalisme bapak
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  48%|████▊     | 1060/2225 [06:37<09:05,  2.13teks/s]
# ✅ Respons diterima (161 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1060 (47.6%)
#   - Total belum berlabel: 1165
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 1060/2225 (47.6%)
#
#
# ==================================================
# 🔖 BATCH 54/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kak Vina gak mau kabur kah ke LN?
#   2. dulu:dirumahaja
# sekarang:kaburajdulu
#   3. kuliah tinggi tinggi,udh duduk diruangan AC tapi g...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▊     | 1080/2225 [06:39<06:45,  2.82teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1080 (48.5%)
#   - Total belum berlabel: 1145
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# 💾 Progress tersimpan: 1080/2225 (48.5%)
#
#
# ==================================================
# 🔖 BATCH 55/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. nasionalisme..biarr ..dari pada makan hasil korup ...
#   2. sumpah aku pgen kabur 🥺
#   3. justru kami ragu dgn kondisi negara kami yg skrg, ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▉     | 1100/2225 [06:42<05:25,  3.46teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1100 (49.4%)
#   - Total belum berlabel: 1125
# 💾 Backup dibuat: label-data/progress_sentiment_3_to_6.csv.bak
# ...
# 🔖 BATCH 95/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ga nasionalisme? yaudah coba syarat kerja di indo ...
#   2. sya juga meragukan kinerja bapk
#   3. jadi ingat kata pak Bj Habibi
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  85%|████████▌ | 1900/2225 [12:17<01:20,  4.06teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1900 (85.4%)
#   - Total belum berlabel: 325
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 1900/2225 (85.4%)
#
#
# ==================================================
# 🔖 BATCH 96/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. jadi gimana? yahhh gas lah belajar BHS asing dan p...
#   2. sekarang gk mikir nasional mikirin perut😭nurutin n...
#   3. Yg penting cuan 😂😂😂😂😂
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  86%|████████▋ | 1920/2225 [12:19<00:59,  5.14teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - netral: 6x (30.0%)
#   - positif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1920 (86.3%)
#   - Total belum berlabel: 305
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 1920/2225 (86.3%)
#
#
# ==================================================
# 🔖 BATCH 97/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bang/kak, mau nanya
# saya sekarang lgi kerja di lua...
#   2. kami rakyat,,butuh makan,biaya hidup,,bukan nasion...
#   3. ajak ajak dong
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  87%|████████▋ | 1940/2225 [12:23<00:57,  4.96teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1940 (87.2%)
#   - Total belum berlabel: 285
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 1940/2225 (87.2%)
#
#
# ==================================================
# 🔖 BATCH 98/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. tungguin bg gua ikut 😂
#   2. aku sepakat yg terakhri
#   3. menuju indonesia emas🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  88%|████████▊ | 1960/2225 [12:25<00:44,  5.99teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1960 (88.1%)
#   - Total belum berlabel: 265
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 1960/2225 (88.1%)
#
#
# ==================================================
# 🔖 BATCH 99/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Menurut aku besok tak buat lapangan pekerjaan 😂
#   2. Kerjaa dpr apa sii, gajinya banyk bgt😭
#   3. nitip salam kak buat bahlil,,,suruh koreksi anggot...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  89%|████████▉ | 1980/2225 [12:27<00:36,  6.66teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - positif: 4x (20.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1980 (89.0%)
#   - Total belum berlabel: 245
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 1980/2225 (89.0%)
#
#
# ==================================================
# 🔖 BATCH 100/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. aku GK pindah pak cuma numpang cari duit, Indonesi...
#   2. pak wargamu nek mbok tantang, dadi pak, malah mngk...
#   3. Bpk baru ragu? kami udh lama ragu ama yg d atas 🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  90%|████████▉ | 2000/2225 [12:29<00:30,  7.45teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2000 (89.9%)
#   - Total belum berlabel: 225
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2000/2225 (89.9%)
#
#
# ==================================================
# 🔖 BATCH 101/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @011L @🧠🫀 gass belajar yg pinter, pindah ke luar n...
#   2. Udah kerja di Jepang 5 tahun jadi PT. emang enak, ...
#   3. emng dia nasionalisme jga?
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  91%|█████████ | 2020/2225 [12:34<00:34,  5.96teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2020 (90.8%)
#   - Total belum berlabel: 205
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2020/2225 (90.8%)
#
#
# ==================================================
# 🔖 BATCH 102/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. emang si bahlil nasionalisme ?
#   2. satu tahun udah di UEA😅
#   3. Jangan dengerin mereka Broo mereka gak keren😹😹
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  92%|█████████▏| 2040/2225 [12:36<00:28,  6.51teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2040 (91.7%)
#   - Total belum berlabel: 185
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2040/2225 (91.7%)
#
#
# ==================================================
# 🔖 BATCH 103/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Aku cinta Indonesia tp indonesia gk cinta aku pak
#   2. Meragukan nasionalisme?,hey bapak emang suda menja...
#   3. meragukan nasionalisme atau
# takut gk bisa korupsi ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2060/2225 [12:38<00:23,  7.13teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - netral: 7x (35.0%)
#   - negatif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2060 (92.6%)
#   - Total belum berlabel: 165
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2060/2225 (92.6%)
#
#
# ==================================================
# 🔖 BATCH 104/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. buat yg single mungkin it's easy buat ambil keputu...
#   2. gua kak dari awal 2017 masuk sampe detik ini gaji ...
#   3. lalu bagaimana dengan yang korupsi apakah ada nasi...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2080/2225 [12:48<00:34,  4.18teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 14x (70.0%)
#   - positif: 5x (25.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2080 (93.5%)
#   - Total belum berlabel: 145
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2080/2225 (93.5%)
#
#
# ==================================================
# 🔖 BATCH 105/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. soonn bakal #kaburajadulu
#   2. apa hubungan nya cari duit sama nasionalisme 😑
#   3. lah bodoh amat pemerintah indonesia maaunya kaya s...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  94%|█████████▍| 2100/2225 [12:53<00:31,  4.00teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2100 (94.4%)
#   - Total belum berlabel: 125
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2100/2225 (94.4%)
#
#
# ==================================================
# 🔖 BATCH 106/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. negara kek gini ngapain di ragukan😂😂😂
#   2. siapa sih Bahlil itu😂, baru denger
#   3. bapak"berkepala lancip bahas nasionalisme 🤣
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  95%|█████████▌| 2120/2225 [12:55<00:21,  4.86teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2120 (95.3%)
#   - Total belum berlabel: 105
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2120/2225 (95.3%)
#
#
# ==================================================
# 🔖 BATCH 107/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mereka masih memikirkan nasionalisme, tanpa berfik...
#   2. upsss
#   3. gw Klo punya duit bnyk sma pintar cus pindah asli,...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  96%|█████████▌| 2140/2225 [12:57<00:14,  5.72teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2140 (96.2%)
#   - Total belum berlabel: 85
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2140/2225 (96.2%)
#
#
# ==================================================
# 🔖 BATCH 108/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yang sudah kenyang uang rakyat teriak nasionalisme...
#   2. bahlil❌
# bahlul✔️
#   3. Nasionalisme? Lu ga salah ngomong gitu
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  97%|█████████▋| 2160/2225 [13:22<00:32,  2.02teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2160 (97.1%)
#   - Total belum berlabel: 65
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2160/2225 (97.1%)
#
#
# ==================================================
# 🔖 BATCH 109/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lawak cik 😂 kalo pergi dari negara lain itu gak na...
#   2. jepang tunggu aku
#   3. tumben pertama 🗿
# ᵏᵒᵐᵉⁿᵗᵃʳ ᵖᵉʳᵗᵃᵐᵃ
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  98%|█████████▊| 2180/2225 [13:24<00:16,  2.67teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2180 (98.0%)
#   - Total belum berlabel: 45
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2180/2225 (98.0%)
#
#
# ==================================================
# 🔖 BATCH 110/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Sebenarnya mau kabur aja dulu. tapi umur dah tua
#   2. pindah aja, ini bukan berbicara nasionalisme, teta...
#   3. Max umur 25 th, goblooking, menguasai air tanah ap...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  99%|█████████▉| 2200/2225 [13:26<00:07,  3.43teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2200 (98.9%)
#   - Total belum berlabel: 25
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2200/2225 (98.9%)
#
#
# ==================================================
# 🔖 BATCH 111/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lagi stay di Malaysia Masih nyaman'' aja ni☺️
#   2. ketua umum Golkar sekalian mentri yg
# Ter Bahlil Ba...
#   3. bener si,keluarga gua rata rata kerja nya di luar ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|█████████▉| 2220/2225 [13:28<00:01,  4.26teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2220 (99.8%)
#   - Total belum berlabel: 5
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2220/2225 (99.8%)
#
#
# ==================================================
# 🔖 BATCH 112/112 (5 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. S1 pendidikan matematika, ppg dipangkas, didaerah ...
#   2. lah biarin jir orang pake duit sendiri ga pake dui...
#   3. gue dah kabur wee malas pulang ke indo sumpah 😂 ka...
#   ... dan 2 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|██████████| 2225/2225 [13:29<00:00,  2.75teks/s]
# ✅ Respons diterima (37 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 2x (40.0%)
#   - netral: 2x (40.0%)
#   - negatif: 1x (20.0%)
# ✅ 5 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2225 (100.0%)
#   - Total belum berlabel: 0
# 💾 Backup dibuat: label-data/progress_sentiment_4_to_6.csv.bak
# 💾 Progress tersimpan: 2225/2225 (100.0%)
#
# 📊 STATISTIK AKHIR:
#   - Total record: 2225
#   - Total teks unik: 2225
#   - Record berlabel: 2225 (100.0%)
#   - Record belum berlabel: 0 (0.0%)
#   - Teks unik berlabel: 2225 (100.0%)
#
# 💾 Menyimpan hasil akhir...
# 🎉 PROSES SELESAI! Hasil disimpan di label-data/labeled_sentiment_4_to_6.csv
#
# ⏱️ Total waktu eksekusi: 13.5 menit
# 📊 Record berlabel: 2225/2225 (100.0%)
# 📊 Teks unik berlabel: 2225/2225 (100.0%)
#
# ============================================================
# SELESAI MEMPROSES CHUNK 4/6
# ============================================================

# %%
for i in range(5, 7):  # proses per 2 chunk
    # Update konfigurasi untuk chunk ini
    INPUT_CSV = f'full-data/result/chunks/chunk_{i}_of_6.csv'
    PROGRESS_CSV = f'label-data/progress_sentiment_{i}_to_6.csv'
    OUTPUT_CSV = f'label-data/labeled_sentiment_{i}_to_6.csv'
    
    # Panggil fungsi main
    print(f"\n\n{'='*60}")
    print(f"MEMULAI PROSES UNTUK CHUNK {i}/6")
    print(f"{'='*60}\n")
    
    # Jalankan proses labeling untuk chunk ini
    main()
    
    print(f"\n{'='*60}")
    print(f"SELESAI MEMPROSES CHUNK {i}/6")
    print(f"{'='*60}\n\n")
# Out:
# ============================================================
# MEMULAI PROSES UNTUK CHUNK 5/6
# ============================================================
#
#
# ==================================================
# 🚀 MEMULAI PROSES LABELING SENTIMENT #KABURAJADULU
# ==================================================
# 📊 Memuat dataset dari full-data/result/chunks/chunk_5_of_6.csv...
# ✅ Dataset berhasil dimuat. Total record: 2225
# 🆕 Membuat file progress baru...
#
# 📊 STATISTIK DATASET:
#   - Total record: 2225
#   - Total teks unik: 2225
#   - Record berlabel: 0 (0.0%)
#   - Record belum berlabel: 2225 (100.0%)
#   - Teks unik belum berlabel: 2225
# 📋 Statistik data yang belum dilabel:
#   - Total record belum berlabel: 2225/2225
#   - Teks unik belum berlabel: 2225
# 🧮 Membagi 2225 teks unik menjadi 112 batch
# 🚀 Progress Labeling:   0%|          | 0/2225 [00:00<?, ?teks/s]
# ==================================================
# 🔖 BATCH 1/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. otw arab
#   2. kita gak makan nasionalisme tapi nasi sama lauk🤣
#   3. kocak lu ah
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   1%|          | 20/2225 [00:04<07:49,  4.70teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 20 (0.9%)
#   - Total belum berlabel: 2205
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 20/2225 (0.9%)
#
#
# ==================================================
# 🔖 BATCH 2/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. tolong klo ada info kerja ke luar negri yg asli be...
#   2. @Ilhamkusumaaa woi ayo kaburr😋😭
#   3. pngen kerja diresto dijepang atau dikorea
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   2%|▏         | 40/2225 [00:15<14:58,  2.43teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 40 (1.8%)
#   - Total belum berlabel: 2185
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 40/2225 (1.8%)
#
#
# ==================================================
# 🔖 BATCH 3/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. makin lama makin menjadi jadi aja nih indonesia🤣🤣🔥...
#   2. jangan bilang ga ada nasionalisme buat rakyat lah ...
#   3. nasionalisme gabisa buat bertahan hidup
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   3%|▎         | 60/2225 [00:19<11:10,  3.23teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 60 (2.7%)
#   - Total belum berlabel: 2165
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 60/2225 (2.7%)
#
#
# ==================================================
# 🔖 BATCH 4/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. otw aussie ah
#   2. YG GAK NASIONALIS ITU PARA PEJABAT YG TIDAK PEDULI...
#   3. "Lucu sekali, dunia sudah serba digital tapi pola ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▎         | 80/2225 [00:23<09:44,  3.67teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 80 (3.6%)
#   - Total belum berlabel: 2145
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 80/2225 (3.6%)
#
#
# ==================================================
# 🔖 BATCH 5/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. woeeee...Tenaga kerja migran penyumbang devisa ter...
#   2. gw lebih ragu sma lo pakk, kocakk ngasih kehidupan...
#   3. punya adik 4 dan udh ga punya bapa,kerja ngelamar ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   4%|▍         | 100/2225 [00:27<08:36,  4.11teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 100 (4.5%)
#   - Total belum berlabel: 2125
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 100/2225 (4.5%)
#
#
# ==================================================
# 🔖 BATCH 6/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @Shelvimey @Yoana Sirait gimna nih ? mau kaburajad...
#   2. #kaburajadlu pengen ke China 😭
#   3. Indonesia sedang di jajah Indonesia sendiri😃👍
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   5%|▌         | 120/2225 [00:28<06:38,  5.28teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 120 (5.4%)
#   - Total belum berlabel: 2105
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 120/2225 (5.4%)
#
#
# ==================================================
# 🔖 BATCH 7/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Nasionalisme gak bisa bikin kenyang pakkk 🤣🤣
#   2. di indo muak jjur aja korupsi dmn2, Hukum tumpul k...
#   3. negara isinya orang orang korupsi org kaya makin k...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   6%|▋         | 140/2225 [00:36<08:34,  4.05teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 140 (6.3%)
#   - Total belum berlabel: 2085
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 140/2225 (6.3%)
#
#
# ==================================================
# 🔖 BATCH 8/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. nabung dulu, soon Aussie amin
#   2. dari sekian banyak negara kenapa gw lahir di Indon...
#   3. jalur semacam bidang seni misal ada manga, illustr...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   7%|▋         | 160/2225 [00:58<18:05,  1.90teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 160 (7.2%)
#   - Total belum berlabel: 2065
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 160/2225 (7.2%)
#
#
# ==================================================
# 🔖 BATCH 9/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gacor bangg🔥🔥
#   2. anak muda wajib memanfaatkan umur yang produktip u...
#   3. di Indonesia syarat kerja harus punya pengalaman, ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   8%|▊         | 180/2225 [01:03<14:40,  2.32teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 180 (8.1%)
#   - Total belum berlabel: 2045
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 180/2225 (8.1%)
#
#
# ==================================================
# 🔖 BATCH 10/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. negara lain aja menghargai, masak yang asli dari n...
#   2. Indonesian: #kaburajadulu
# jepang: #datangajadulu
#   3. #kaburajadulu jepang😋
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:   9%|▉         | 200/2225 [01:05<11:06,  3.04teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 200 (9.0%)
#   - Total belum berlabel: 2025
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 200/2225 (9.0%)
#
#
# ==================================================
# 🔖 BATCH 11/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bro Mulyono tidak tahu cara bermain gen z😹
#   2. info loker bu😁
#   3. mungkin klo rakyat bukan lagi meragukan nasionalis...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  10%|▉         | 220/2225 [01:18<14:19,  2.33teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 220 (9.9%)
#   - Total belum berlabel: 2005
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 220/2225 (9.9%)
#
#
# ==================================================
# 🔖 BATCH 12/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. negara lain meraih mimpi, indonesia? hanya minpi😹😹
#   2. Harusnya pemerintah jdi mikir kenapa warga indo sp...
#   3. klu pak Bahlil punya nasionalisme, kok Rempang di ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  11%|█         | 240/2225 [01:36<19:05,  1.73teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 240 (10.8%)
#   - Total belum berlabel: 1985
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 240/2225 (10.8%)
#
#
# ==================================================
# 🔖 BATCH 13/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. hti" aja deh,jngn terlalu fomo,bukan ngelarang,lam...
#   2. setuju sama abang nya
# ya bodoamat 👍😁😂😂
#   3. oneday ya Allah
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  12%|█▏        | 260/2225 [01:38<14:08,  2.32teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 260 (11.7%)
#   - Total belum berlabel: 1965
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 260/2225 (11.7%)
#
#
# ==================================================
# 🔖 BATCH 14/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Kerja serius gajih bercanda
# #kaburAjadulu
#   2. ngapain dengerin bahlul brengsek
# langsung cabut aj...
#   3. satu kata untuk pem*rintah,, GBLKK
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 280/2225 [01:40<10:49,  2.99teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 280 (12.6%)
#   - Total belum berlabel: 1945
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 280/2225 (12.6%)
#
#
# ==================================================
# 🔖 BATCH 15/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Indonesia negara' yg baik pemerintah nya dongo
#   2. nasionalisme tidak membuat hidup
#   3. knp p.Bahl g meragukan nasionalisme para koruptor,...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  13%|█▎        | 300/2225 [01:42<08:21,  3.83teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 300 (13.5%)
#   - Total belum berlabel: 1925
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 300/2225 (13.5%)
#
#
# ==================================================
# 🔖 BATCH 16/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @I'm @prn🌷 😂😂
#   2. buat kalian dbwah 25 kabur aja dulu
#   3. batas umur,dikira yang tua udah ga perlu mkan🗿
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  14%|█▍        | 320/2225 [01:46<07:53,  4.02teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 320 (14.4%)
#   - Total belum berlabel: 1905
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 320/2225 (14.4%)
#
#
# ==================================================
# 🔖 BATCH 17/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. #kaburajadulu jadi pengen ke us 🗿tapi gw masih boc...
#   2. wkwkwkwkwkwkwkwkw kocak
#   3. negaraku 🥲
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  15%|█▌        | 340/2225 [02:01<12:15,  2.56teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 12x (60.0%)
#   - negatif: 4x (20.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 340 (15.3%)
#   - Total belum berlabel: 1885
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 340/2225 (15.3%)
#
#
# ==================================================
# 🔖 BATCH 18/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pengalaman kerja minimal 5 tahun dibidang yang sam...
#   2. yg penting doet ya
#   3. mau kabur tapi ortu udh berumur bgt, ga tega ningg...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  16%|█▌        | 360/2225 [02:34<24:08,  1.29teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 360 (16.2%)
#   - Total belum berlabel: 1865
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 360/2225 (16.2%)
#
#
# ==================================================
# 🔖 BATCH 19/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ikut kabur kuy @JustJee @Love stay🥟 @nkg_gaa
#   2. mreka TDK menyadri klw itu bahasa² kritik dari msy...
#   3. memulai hidup baru ke china
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  17%|█▋        | 380/2225 [02:36<17:26,  1.76teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 12x (60.0%)
#   - positif: 7x (35.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 380 (17.1%)
#   - Total belum berlabel: 1845
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 380/2225 (17.1%)
#
#
# ==================================================
# 🔖 BATCH 20/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Yuk ke jepang aja soalnya disana lagi butuh orang
#   2. apa aku ikut #kaburajadulu ya? soalnya udah retusa...
#   3. gmn gk pindah kerja aj harus es teler dl tinggi ha...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  18%|█▊        | 400/2225 [02:39<13:19,  2.28teks/s]
# ✅ Respons diterima (164 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 400 (18.0%)
#   - Total belum berlabel: 1825
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 400/2225 (18.0%)
#
#
# ==================================================
# 🔖 BATCH 21/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Bila cinta tidak terbalas… kami cinta Indonesia 🇮🇩...
#   2. realistis sih, saya juga kalo banyak duit mending ...
#   3. yaa malah ak pgen bgt krja dluar negri, gaji 1 BLN...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  19%|█▉        | 420/2225 [03:11<23:43,  1.27teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - negatif: 4x (20.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 420 (18.9%)
#   - Total belum berlabel: 1805
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 420/2225 (18.9%)
#
#
# ==================================================
# 🔖 BATCH 22/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. jujur aja ka,kita disini lebih sejahtera😭
#   2. mau ikuutttt😭
#   3. wa are hiring
# kami lagi bukak lowongan kerja
# posis...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  20%|█▉        | 440/2225 [03:13<17:16,  1.72teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - negatif: 5x (25.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 440 (19.8%)
#   - Total belum berlabel: 1785
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 440/2225 (19.8%)
#
#
# ==================================================
# 🔖 BATCH 23/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. terserah lu dah paaaaakkkkk!!!!!
#   2. itu pertanda di dalam negeri belum bisa menjamin k...
#   3. kamu enak pak kerjanya
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  21%|██        | 460/2225 [03:17<13:46,  2.14teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - netral: 4x (20.0%)
#   - positif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 460 (20.7%)
#   - Total belum berlabel: 1765
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 460/2225 (20.7%)
#
#
# ==================================================
# 🔖 BATCH 24/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Cara nyari kerja di jepang gimna si😭
#   2. Ada uang sangu mah uda jauh2 hari uda pindah dari ...
#   3. aku udah kabur dari tahun 2010
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 480/2225 [03:20<10:47,  2.69teks/s]
# ✅ Respons diterima (165 karakter)
# ⚠️ Jumlah label (21) tidak sesuai dengan jumlah teks (20)
# ✂️ Memotong ke 20 label
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 480 (21.6%)
#   - Total belum berlabel: 1745
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 480/2225 (21.6%)
#
#
# ==================================================
# 🔖 BATCH 25/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Dajjal Bahlil. Peliharaan Pejabat. 270T woi jangan...
#   2. Swiss juga enak loh
#   3. yg penting jgn pindah ke Malaysia 🤣🤣🤣🤣🤣 tidak dial...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  22%|██▏       | 500/2225 [03:22<08:18,  3.46teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 500 (22.5%)
#   - Total belum berlabel: 1725
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 500/2225 (22.5%)
#
#
# ==================================================
# 🔖 BATCH 26/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mantap kak
#   2. @.why.⁉️
#   3. kalo negara dah sukses,lu mau balik gitu woyyyy ci...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  23%|██▎       | 520/2225 [03:26<07:32,  3.77teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 520 (23.4%)
#   - Total belum berlabel: 1705
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 520/2225 (23.4%)
#
#
# ==================================================
# 🔖 BATCH 27/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Realistis aja pak, negeri ini secintacintanya kami...
#   2. udah kuliah sampai s2, ujungnya pengangguran
#   3. negara impian gw😢
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  24%|██▍       | 540/2225 [03:30<07:07,  3.95teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 6x (30.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 540 (24.3%)
#   - Total belum berlabel: 1685
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 540/2225 (24.3%)
#
#
# ==================================================
# 🔖 BATCH 28/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @D🌶️ aku tim sdh di luar negeri 🤤🤤
#   2. gaji d luar negri gede ktimbang di indo . ya jelas...
#   3. orang diindonesia aja nasionalismenya gak dihargai...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  25%|██▌       | 560/2225 [03:38<08:09,  3.40teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 560 (25.2%)
#   - Total belum berlabel: 1665
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 560/2225 (25.2%)
#
#
# ==================================================
# 🔖 BATCH 29/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Ngeri sekali warga konoha ini, padahal di pertamba...
#   2. @asnande koyok kue😂
#   3. Dia nanyain pendapat orang, pendapat dia kagak ada...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  26%|██▌       | 580/2225 [03:43<07:49,  3.50teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 580 (26.1%)
#   - Total belum berlabel: 1645
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 580/2225 (26.1%)
#
#
# ==================================================
# 🔖 BATCH 30/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pengen juga ke luar negri,kerja di sana enak kali ...
#   2. Nasionalisme?!
# Coba kau bilang begitu di depan waj...
#   3. sbenernya ak pengen pindah negara .cuma ga punya d...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  27%|██▋       | 600/2225 [03:46<06:32,  4.14teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - negatif: 6x (30.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 600 (27.0%)
#   - Total belum berlabel: 1625
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 600/2225 (27.0%)
#
#
# ==================================================
# 🔖 BATCH 31/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. gw kalo GK mentok umur udah kabur juga bang,😇
#   2. gausa ngomongin nasionalisme, pancasila sila ke 5 ...
#   3. Lucunya Negeriku
# pekerjaan di Konoha Sulit, Persya...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  28%|██▊       | 620/2225 [03:48<05:13,  5.13teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 8x (40.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 620 (27.9%)
#   - Total belum berlabel: 1605
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 620/2225 (27.9%)
#
#
# ==================================================
# 🔖 BATCH 32/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. eh....pak buat apa nasionalisme di ributin org per...
#   2. 5 tahun di Malaysia, dan ini terbang lagi ke Hunga...
#   3. cara awalnya gmn ya aku nyesel lahir d Indonesia b...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  29%|██▉       | 640/2225 [03:52<05:09,  5.13teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 640 (28.8%)
#   - Total belum berlabel: 1585
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 640/2225 (28.8%)
#
#
# ==================================================
# 🔖 BATCH 33/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. loooosss gk perduli
#   2. lebih setuju hidup di luar negri dri pada indonesi...
#   3. anak ku aja dah ku ajarin
# tmat TK SD SMP siap itu ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  30%|██▉       | 660/2225 [03:58<05:48,  4.49teks/s]
# ✅ Respons diterima (151 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - netral: 8x (40.0%)
#   - negatif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 660 (29.7%)
#   - Total belum berlabel: 1565
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 660/2225 (29.7%)
#
#
# ==================================================
# 🔖 BATCH 34/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. semakin ngeriii gen Z skrg....wkwkwk....gasss....a...
#   2. keren kata-kata abang😂😂😂😂😂😂😂😂
#   3. harus lu mikir lil
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███       | 680/2225 [03:59<04:41,  5.48teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 680 (30.6%)
#   - Total belum berlabel: 1545
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 680/2225 (30.6%)
#
#
# ==================================================
# 🔖 BATCH 35/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. aku yang tua juga Pngin gas mending ke LN Mas
#   2. masyarakat malahan yg meragukan mu, ini slah 1 ana...
#   3. stress nih negara😁
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  31%|███▏      | 700/2225 [04:13<08:27,  3.01teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 700 (31.5%)
#   - Total belum berlabel: 1525
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 700/2225 (31.5%)
#
#
# ==================================================
# 🔖 BATCH 36/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. wahhhhhhhh.pen triak hidup di indo
#   2. menyala king 🔥
#   3. yang harus di ragukan itu pejabat indo ga si wkwk
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  32%|███▏      | 720/2225 [04:17<07:16,  3.45teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 720 (32.4%)
#   - Total belum berlabel: 1505
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 720/2225 (32.4%)
#
#
# ==================================================
# 🔖 BATCH 37/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bkn tidak cinta negara sendiri(indonesia)tpi di in...
#   2. nasionalisme gabikin masa depan cerah!kalo ada pel...
#   3. emng nya kmu mikirin rakyattt??? LUCU YA KAMU
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  33%|███▎      | 740/2225 [04:21<06:28,  3.82teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 740 (33.3%)
#   - Total belum berlabel: 1485
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 740/2225 (33.3%)
#
#
# ==================================================
# 🔖 BATCH 38/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. semakin di ejek
# semakin tertantang yok pindah"🗿
#   2. menurut ku emang ga mudah sih , ya semoga perkerja...
#   3. BAWA AKU KBUR PLZ😫
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  34%|███▍      | 760/2225 [04:22<05:05,  4.79teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - netral: 6x (30.0%)
#   - negatif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 760 (34.2%)
#   - Total belum berlabel: 1465
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 760/2225 (34.2%)
#
#
# ==================================================
# 🔖 BATCH 39/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Doain ya lulus nanti aku bisa memulai hidup baru d...
#   2. Buktinya aja 100 hari masa kerja, menteri bahlil i...
#   3. ini bkn soal nasionalisme pak tapi d indo susah ca...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  35%|███▌      | 780/2225 [04:28<05:23,  4.47teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 6x (30.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 780 (35.1%)
#   - Total belum berlabel: 1445
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 780/2225 (35.1%)
#
#
# ==================================================
# 🔖 BATCH 40/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. standar tiktok🗿
#   2. gimana pada ga kabur..
# gaji ponakan jadi koas dokt...
#   3. rasa nasionalisme gua malah muncul pas event olahr...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  36%|███▌      | 800/2225 [04:30<04:25,  5.36teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - netral: 7x (35.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 800 (36.0%)
#   - Total belum berlabel: 1425
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 800/2225 (36.0%)
#
#
# ==================================================
# 🔖 BATCH 41/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. negeri ini udah kebanyakan judi
#   2. aku dukung #kaburajadulu tp dikomen sma org suruh ...
#   3. kapok jatuh kan😂
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  37%|███▋      | 820/2225 [04:38<05:51,  4.00teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 820 (36.9%)
#   - Total belum berlabel: 1405
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 820/2225 (36.9%)
#
#
# ==================================================
# 🔖 BATCH 42/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. lagu Tanah airku bait ke 2🔥
#   2. pingin ikut kabur🥺
#   3. kalo kalian pada pindah...
# gimana nasib negara ter...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  38%|███▊      | 840/2225 [04:42<05:38,  4.09teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - netral: 6x (30.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 840 (37.8%)
#   - Total belum berlabel: 1385
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 840/2225 (37.8%)
#
#
# ==================================================
# 🔖 BATCH 43/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. klw ada yang bilang di luar negeri gak mandang ija...
#   2. bahlul😂😂😂
#   3. soon, I will meet my American husband and live in ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  39%|███▊      | 860/2225 [04:44<04:24,  5.15teks/s]
# ✅ Respons diterima (151 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - netral: 8x (40.0%)
#   - positif: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 860 (38.7%)
#   - Total belum berlabel: 1365
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 860/2225 (38.7%)
#
#
# ==================================================
# 🔖 BATCH 44/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. doain bisa nyusul
#   2. padahal hidup di indo juga enak tau, kalo kaya😁
#   3. Sapa bang
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|███▉      | 880/2225 [05:02<09:21,  2.40teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 880 (39.6%)
#   - Total belum berlabel: 1345
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 880/2225 (39.6%)
#
#
# ==================================================
# 🔖 BATCH 45/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. aku mauu😥
#   2. kenapa bapak marah? karena yg kabur pada berpendid...
#   3. kerja serius gaji bercanda🤣😂🤣🤭# kaburajadulu#
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  40%|████      | 900/2225 [05:04<06:59,  3.16teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 12x (60.0%)
#   - negatif: 7x (35.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 900 (40.4%)
#   - Total belum berlabel: 1325
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 900/2225 (40.4%)
#
#
# ==================================================
# 🔖 BATCH 46/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Wah di posting ulang nyai nikmir
#   2. @Fahriansyah 👀:Indonesian akan bubar di karenakan ...
#   3. @๋࣭ ⭑⚝๋࣭ ⭑stranger's๋࣭ ⭑⚝๋࣭ ⭑ ayo kaburr best😭stre...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  41%|████▏     | 920/2225 [05:06<05:21,  4.06teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - positif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 920 (41.3%)
#   - Total belum berlabel: 1305
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 920/2225 (41.3%)
#
#
# ==================================================
# 🔖 BATCH 47/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. warga Indonesia ditantangin 🗿
#   2. dicari lowongan kerja ...jualan es teh jumbo dari ...
#   3. @partaigerindra min😑
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  42%|████▏     | 940/2225 [05:14<06:20,  3.38teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 11x (55.0%)
#   - negatif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 940 (42.2%)
#   - Total belum berlabel: 1285
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 940/2225 (42.2%)
#
#
# ==================================================
# 🔖 BATCH 48/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Rakyat : Saya malah meragukan nasionalisme para pe...
#   2. hello bali
#   3. semoga aku juga bisa
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  43%|████▎     | 960/2225 [05:16<04:54,  4.30teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 8x (40.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 960 (43.1%)
#   - Total belum berlabel: 1265
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 960/2225 (43.1%)
#
#
# ==================================================
# 🔖 BATCH 49/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. @Ade FANA gae kyk ngene jaa🤣
#   2. sarjana banyak loker dikit giliran ada loker sesua...
#   3. MACAM MANA NGANK PINDAH...WONG PEJABATNYA SEMUA BR...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  44%|████▍     | 980/2225 [05:47<13:11,  1.57teks/s]
# ✅ Respons diterima (158 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 9x (45.0%)
#   - netral: 1x (5.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 980 (44.0%)
#   - Total belum berlabel: 1245
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 980/2225 (44.0%)
#
#
# ==================================================
# 🔖 BATCH 50/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bahlil tolong kebijakan gas lpg 3kg mu nyusahin ma...
#   2. di indo gue nganggur mulu, masalahnya pengen kerja...
#   3. di luar negri ibaratnya tenang tikus" gak ada
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  45%|████▍     | 1000/2225 [05:51<10:19,  1.98teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - netral: 6x (30.0%)
#   - positif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1000 (44.9%)
#   - Total belum berlabel: 1225
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1000/2225 (44.9%)
#
#
# ==================================================
# 🔖 BATCH 51/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yokkk lahh #KaburAjaDulu
#   2. pengen bgt ikut pindah,tapi punya anak🥺mm
#   3. setuju massseh....nadionalisme ngga menjamin masa ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  46%|████▌     | 1020/2225 [05:55<08:06,  2.48teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - netral: 7x (35.0%)
#   - negatif: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1020 (45.8%)
#   - Total belum berlabel: 1205
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1020/2225 (45.8%)
#
#
# ==================================================
# 🔖 BATCH 52/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. kalo bahlil ini nasionalisme tinggi coba gajinya b...
#   2. suka suka gua mawu ke negara siapa tujuan gua cuma...
#   3. cinta bertepuk sebelah tangan.
# jika hanya di manfa...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  47%|████▋     | 1040/2225 [06:15<11:36,  1.70teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 5x (25.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1040 (46.7%)
#   - Total belum berlabel: 1185
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1040/2225 (46.7%)
#
#
# ==================================================
# 🔖 BATCH 53/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. mau makan apa dengan nasionalisme😂
#   2. aman aman aja sih,tapi jangan sampai mintak jemput...
#   3. gw takutnya dari ramai nya trend ini ada oknum yan...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  48%|████▊     | 1060/2225 [06:17<08:40,  2.24teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 11x (55.0%)
#   - positif: 7x (35.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1060 (47.6%)
#   - Total belum berlabel: 1165
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1060/2225 (47.6%)
#
#
# ==================================================
# 🔖 BATCH 54/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Buat apa kita perjuangkan nasionalisme tapi pejaba...
#   2. semoga selalu dalam lindungan Allah dan sukses..💪
#   3. mana yg lebih nasionalis, menjadi korup atau mengh...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▊     | 1080/2225 [06:19<06:35,  2.89teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 10x (50.0%)
#   - negatif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1080 (48.5%)
#   - Total belum berlabel: 1145
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1080/2225 (48.5%)
#
#
# ==================================================
# 🔖 BATCH 55/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. nasionalisme ngak bisa buat perut kenyang
# pak,yg l...
#   2. merantau lah nasional itu urusan nya d hti mu
#   3. -4 terbang russia
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  49%|████▉     | 1100/2225 [06:36<09:15,  2.02teks/s]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1100 (49.4%)
#   - Total belum berlabel: 1125
# 💾 Backup dibuat: label-data/progress_sentiment_5_to_6.csv.bak
# 💾 Progress tersimpan: 1100/2225 (49.4%)
#
#
# ...
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1880/2225 (84.5%)
#
#
# ==================================================
# 🔖 BATCH 95/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pengen ikut #kaburajadulu tapi masih smp😹🙏
#   2. semuanya omon omon dwg angka pengangguran makin ti...
#   3. sebesar apasih jiwa nasionalisme bapak😹😹😹
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  85%|████████▌ | 1900/2225 [07:00<01:01,  5.27teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - positif: 5x (25.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1900 (85.4%)
#   - Total belum berlabel: 325
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1900/2225 (85.4%)
#
#
# ==================================================
# 🔖 BATCH 96/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Tutor kak
#   2. 2030 bubar
#   3. pengennya si cari pengalaman diluar indo, tapi ind...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  86%|████████▋ | 1920/2225 [07:05<01:00,  5.00teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - netral: 7x (35.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1920 (86.3%)
#   - Total belum berlabel: 305
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1920/2225 (86.3%)
#
#
# ==================================================
# 🔖 BATCH 97/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yok bisa yokk cari pengalaman kerja diluar negeri
#   2. ni mahkota mu king👑
#   3. bapak enak ngomong gt karena udah banyak duit, hid...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  87%|████████▋ | 1940/2225 [07:10<01:02,  4.54teks/s]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - netral: 6x (30.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1940 (87.2%)
#   - Total belum berlabel: 285
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1940/2225 (87.2%)
#
#
# ==================================================
# 🔖 BATCH 98/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. loh kalo meragukan nasionalisme kita, anda harusny...
#   2. keliatanya asik v gw takut mudah se'eul angen😂😂😂
#   3. 😂😂😂😂saya yg ragu nasionalisme anda pak Bahlil...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  88%|████████▊ | 1960/2225 [07:13<00:51,  5.15teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 9x (45.0%)
#   - negatif: 6x (30.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1960 (88.1%)
#   - Total belum berlabel: 265
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1960/2225 (88.1%)
#
#
# ==================================================
# 🔖 BATCH 99/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. ini lama' jadi anime gwa🗿
#   2. klo gw dksh peluang mnding pilih luar negri lahhhh...
#   3. Alhamdulillah aku masih betah di Malaysia penak ga...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  89%|████████▉ | 1980/2225 [07:16<00:46,  5.23teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - positif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 1980 (89.0%)
#   - Total belum berlabel: 245
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 1980/2225 (89.0%)
#
#
# ==================================================
# 🔖 BATCH 100/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bertahan hidup lebih penting🙏
#   2. saya Cinta Uang ❤️❤️❤️❤️❤️
#   3. pengen ikut trend ini 😫
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  90%|████████▉ | 2000/2225 [07:21<00:44,  5.00teks/s]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2000 (89.9%)
#   - Total belum berlabel: 225
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2000/2225 (89.9%)
#
#
# ==================================================
# 🔖 BATCH 101/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. cara pindah bos
#   2. dulu
# #dirumahaja
# sekrng
# #kaburajadulu
# 😂😂😂
#   3. aamin
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  91%|█████████ | 2020/2225 [07:24<00:37,  5.51teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 13x (65.0%)
#   - positif: 4x (20.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2020 (90.8%)
#   - Total belum berlabel: 205
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2020/2225 (90.8%)
#
#
# ==================================================
# 🔖 BATCH 102/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pak prabowo nasionalismenya diragukan pak bahlil t...
#   2. kita kabur aja dlu
#   3. luar negeri hanya tempat pelarian AZ.. nyatanya se...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  92%|█████████▏| 2040/2225 [07:41<01:12,  2.57teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 13x (65.0%)
#   - negatif: 5x (25.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2040 (91.7%)
#   - Total belum berlabel: 185
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2040/2225 (91.7%)
#
#
# ==================================================
# 🔖 BATCH 103/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. klo mau enak tinggal di indo harus kaya harus berp...
#   2. kan sdh banyak para politisi dan pejabat yg mengat...
#   3. doain bg, aku habis lulus smk mau magang di jepang...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2060/2225 [07:44<00:52,  3.13teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 9x (45.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2060 (92.6%)
#   - Total belum berlabel: 165
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2060/2225 (92.6%)
#
#
# ==================================================
# 🔖 BATCH 104/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. #kaburajadulu (Taiwan)
#   2. Ya Allah izinkanlah saya dan keluarga saya utk bis...
#   3. yang kabur, kabur aja gpp kok
# nanti klau ada apa2 ...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  93%|█████████▎| 2080/2225 [07:46<00:35,  4.03teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 7x (35.0%)
#   - netral: 7x (35.0%)
#   - negatif: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2080 (93.5%)
#   - Total belum berlabel: 145
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2080/2225 (93.5%)
#
#
# ==================================================
# 🔖 BATCH 105/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Malaysia enak cari kerja gajinya lumayan di Indone...
#   2. @yukii-sann #kaburajadulu
#   3. sediakan lapangan kerja sesuai dgn jumlah penduduk...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  94%|█████████▍| 2100/2225 [07:48<00:26,  4.71teks/s]
# ✅ Respons diterima (152 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - netral: 7x (35.0%)
#   - positif: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2100 (94.4%)
#   - Total belum berlabel: 125
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2100/2225 (94.4%)
#
#
# ==================================================
# 🔖 BATCH 106/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. Gak ada nasioanlisme pak kalo masalah uang 🤭 kita ...
#   2. Ngmong nasionalisme, sndirinya nasionalismenya man...
#   3. coba aja dulu mana tau wkwk
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  95%|█████████▌| 2120/2225 [07:53<00:22,  4.67teks/s]
# ✅ Respons diterima (156 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 10x (50.0%)
#   - positif: 7x (35.0%)
#   - netral: 3x (15.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2120 (95.3%)
#   - Total belum berlabel: 105
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2120/2225 (95.3%)
#
#
# ==================================================
# 🔖 BATCH 107/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. pendapat dari ka Vina gmn? kalo soal beritanya kit...
#   2. 2 Minggu lagi mau ke jepang,doain teman² semoga la...
#   3. Mending ke tetangga dlu
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  96%|█████████▌| 2140/2225 [07:56<00:16,  5.22teks/s]
# ✅ Respons diterima (157 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 14x (70.0%)
#   - positif: 4x (20.0%)
#   - netral: 2x (10.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2140 (96.2%)
#   - Total belum berlabel: 85
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2140/2225 (96.2%)
#
#
# ==================================================
# 🔖 BATCH 108/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. yg membuat kerugian negara juga dong harus diperta...
#   2. @Gibran Rakabuming @gerindra @NanyonimaINC.
#   3. kuliah habis puluhan juta pas lulus gjiny UMR 2 jt
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  97%|█████████▋| 2160/2225 [09:40<01:50,  1.70s/teks]
# ✅ Respons diterima (154 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 7x (35.0%)
#   - netral: 5x (25.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2160 (97.1%)
#   - Total belum berlabel: 65
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2160/2225 (97.1%)
#
#
# ==================================================
# 🔖 BATCH 109/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. temen temen
#   2. one day...
#   3. gua susul 2thn lagi wkwk
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  98%|█████████▊| 2180/2225 [09:44<00:56,  1.25s/teks]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 8x (40.0%)
#   - positif: 8x (40.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2180 (98.0%)
#   - Total belum berlabel: 45
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2180/2225 (98.0%)
#
#
# ==================================================
# 🔖 BATCH 110/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. nasionalisme Bahlil d ragukan karena sering .........
#   2. saya yang malah meragukan nasionalisme Bahlil...
#   3. kmii jauhh lbihhh raguuu sm bpk 😅
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling:  99%|█████████▉| 2200/2225 [10:08<00:30,  1.23s/teks]
# ✅ Respons diterima (155 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 9x (45.0%)
#   - positif: 7x (35.0%)
#   - netral: 4x (20.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2200 (98.9%)
#   - Total belum berlabel: 25
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2200/2225 (98.9%)
#
#
# ==================================================
# 🔖 BATCH 111/112 (20 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. bahlil ❌
# bahlul ✅
#   2. #kaburajadulu
# cewek umur 26 uda ga msuk PT aplgi c...
#   3. Yaa gimana yaa,, yang kabur gue kenapa situ yang r...
#   ... dan 17 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|█████████▉| 2220/2225 [10:23<00:05,  1.09s/teks]
# ✅ Respons diterima (153 karakter)
# 🏷️ Label terdeteksi:
#   - positif: 8x (40.0%)
#   - negatif: 6x (30.0%)
#   - netral: 6x (30.0%)
# ✅ 20 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2220 (99.8%)
#   - Total belum berlabel: 5
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2220/2225 (99.8%)
#
#
# ==================================================
# 🔖 BATCH 112/112 (5 teks unik)
# ==================================================
#
# 🔍 Contoh teks yang akan dilabel:
#   1. MAUUU, semoga aku bisa ikutan juga
#   2. nabi menganjurkan bwt hijrah u/yg lebih baik om......
#   3. persyaratan seabrek, kerjaan segambreng, gaji seup...
#   ... dan 2 lainnya
# 🤖 Memanggil API (percobaan 1/5, temp=0.20)...
# 🚀 Progress Labeling: 100%|██████████| 2225/2225 [10:26<00:00,  3.55teks/s]
# ✅ Respons diterima (38 karakter)
# 🏷️ Label terdeteksi:
#   - negatif: 2x (40.0%)
#   - positif: 2x (40.0%)
#   - netral: 1x (20.0%)
# ✅ 5 teks unik diterapkan ke 0 record yang belum berlabel
# 📊 Verifikasi sebelum menyimpan:
#   - Total record: 2225
#   - Total berlabel: 2225 (100.0%)
#   - Total belum berlabel: 0
# 💾 Backup dibuat: label-data/progress_sentiment_6_to_6.csv.bak
# 💾 Progress tersimpan: 2225/2225 (100.0%)
#
# 📊 STATISTIK AKHIR:
#   - Total record: 2225
#   - Total teks unik: 2225
#   - Record berlabel: 2225 (100.0%)
#   - Record belum berlabel: 0 (0.0%)
#   - Teks unik berlabel: 2225 (100.0%)
#
# 💾 Menyimpan hasil akhir...
# 🎉 PROSES SELESAI! Hasil disimpan di label-data/labeled_sentiment_6_to_6.csv
#
# ⏱️ Total waktu eksekusi: 10.4 menit
# 📊 Record berlabel: 2225/2225 (100.0%)
# 📊 Teks unik berlabel: 2225/2225 (100.0%)
#
# ============================================================
# SELESAI MEMPROSES CHUNK 6/6
# ============================================================

# %% [markdown]
# ## 🔄 **Penjelasan Kode Penggabungan File Sentimen**
#
# ### ⚙️ **Fungsi Utama: `merge_sentiment_files()`**
#
# Kode ini berfungsi untuk menggabungkan beberapa file CSV hasil labeling sentimen menjadi satu file tunggal. Sederhananya, kode melakukan proses:
#
# 1. **Identifikasi File** - Mendaftarkan semua file CSV hasil labeling yang perlu digabungkan
# 2. **Pembacaan Data** - Membaca setiap file CSV dan menyimpannya sebagai DataFrame
# 3. **Penggabungan** - Menggabungkan semua DataFrame menjadi satu dataset tunggal
# 4. **Analisis** - Menyajikan statistik dari dataset gabungan
# 5. **Penyimpanan** - Menyimpan hasil penggabungan ke file CSV baru
#
# ### 📈 **Output yang Dihasilkan**
#
# Hasil akhir dari kode ini adalah:
#
# 1. **File CSV Gabungan** - Dataset tunggal yang berisi semua record dari seluruh chunk
# 2. **Laporan Statistik** - Tampilan distribusi label sentimen dari keseluruhan dataset
# 3. **Informasi Validasi** - Peringatan tentang adanya duplikat jika terdeteksi
#
# Dengan dataset gabungan ini, analisis sentimen komprehensif terhadap topik "#KaburAjaDulu" dapat dilakukan secara menyeluruh.

# %%
# Directory where your labeled files are stored
input_dir = 'label-data/'
# Output file path
output_file = 'label-data/labeled_sentiment_combined.csv'

def merge_sentiment_files():
    print("🔄 Starting the merging process...")
    
    # List all the CSV files to merge
    files_to_merge = [
        'labeled_sentiment_1_to_6.csv',
        'labeled_sentiment_2_to_6.csv',
        'labeled_sentiment_3_to_6.csv',
        'labeled_sentiment_4_to_6.csv',
        'labeled_sentiment_5_to_6.csv',
        'labeled_sentiment_6_to_6.csv'
    ]
    
    # Create an empty list to store DataFrames
    dataframes = []
    total_records = 0
    
    # Read each file and append to the list
    for file_name in files_to_merge:
        file_path = os.path.join(input_dir, file_name)
        
        # Check if file exists
        if not os.path.exists(file_path):
            print(f"⚠️ Warning: File {file_path} not found. Skipping.")
            continue
        
        print(f"📄 Reading file: {file_name}")
        df = pd.read_csv(file_path)
        
        # Print statistics for this file
        records = len(df)
        labeled = df['sentiment_label'].notna().sum()
        
        print(f"  - Records: {records}")
        print(f"  - Labeled: {labeled} ({labeled/records*100:.1f}%)")
        
        dataframes.append(df)
        total_records += records
    
    # Combine all dataframes
    if not dataframes:
        print("❌ No files found to merge. Please check the file paths.")
        return
    
    print("\n🔄 Combining all dataframes...")
    combined_df = pd.concat(dataframes, ignore_index=True)
    
    # Verify the column consistency
    print(f"\n📊 Combined dataset statistics:")
    print(f"  - Total records: {len(combined_df)}")
    
    # Check for sentiment label stats
    labeled_count = combined_df['sentiment_label'].notna().sum()
    print(f"  - Records with sentiment labels: {labeled_count} ({labeled_count/len(combined_df)*100:.1f}%)")
    
    # Check for duplicates
    duplicates = combined_df.duplicated(subset=['extracted_text']).sum()
    if duplicates > 0:
        print(f"⚠️ Found {duplicates} duplicate records. You may want to deduplicate the dataset.")
    
    # Count distribution of sentiment labels
    label_counts = combined_df['sentiment_label'].value_counts()
    print("\n📊 Sentiment label distribution:")
    for label, count in label_counts.items():
        print(f"  - {label}: {count} ({count/labeled_count*100:.1f}%)")
    
    # Save the combined dataset
    print(f"\n💾 Saving combined dataset to {output_file}...")
    combined_df.to_csv(output_file, index=False)
    print("✅ Merging completed successfully!")
    
    return combined_df

# Run the merging process
if __name__ == "__main__":
    merge_sentiment_files()
# Out:
# 🔄 Starting the merging process...
# 📄 Reading file: labeled_sentiment_1_to_6.csv
#   - Records: 2226
#   - Labeled: 2226 (100.0%)
# 📄 Reading file: labeled_sentiment_2_to_6.csv
#   - Records: 2226
#   - Labeled: 2226 (100.0%)
# 📄 Reading file: labeled_sentiment_3_to_6.csv
#   - Records: 2225
#   - Labeled: 2225 (100.0%)
# 📄 Reading file: labeled_sentiment_4_to_6.csv
#   - Records: 2225
#   - Labeled: 2225 (100.0%)
# 📄 Reading file: labeled_sentiment_5_to_6.csv
#   - Records: 2225
#   - Labeled: 2225 (100.0%)
# 📄 Reading file: labeled_sentiment_6_to_6.csv
#   - Records: 2225
#   - Labeled: 2225 (100.0%)
#
# 🔄 Combining all dataframes...
#
# 📊 Combined dataset statistics:
#   - Total records: 13352
#   - Records with sentiment labels: 13352 (100.0%)
#
# 📊 Sentiment label distribution:
#   - negatif: 5482 (41.1%)
#   - positif: 5187 (38.8%)
#   - netral: 2683 (20.1%)
#
# 💾 Saving combined dataset to label-data/labeled_sentiment_combined.csv...
# ✅ Merging completed successfully!
